# %%
import pandas as pd 
import numpy as np

# %%
df_ventas_totales = pd.read_csv("VENTAS_TOTALES.csv",delimiter=";")
df_ventas_totales.head()
# Out:
#    SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0  GOBIERNO      OnLine         1             330.0          125
# 1       NaN     Mailing         1            1834.0           20
# 2       NaN  Sucursales         1            2416.0          125
# 3   EMPRESA      OnSite         1               NaN           20
# 4  GOBIERNO      OnLine         1            1023.0          125
#
#    IMPORTEVENTAS FECHAVENTA  DIAVENTA  MESVENTA  ANIOVENTA NOMBREPRODUCTO
# 0           5000   1/9/2013         1         9       2013           mesa
# 1          36680   1/9/2013         1         9       2013           MESA
# 2         302000   1/9/2013         1         9       2013           MESA
# 3           8840   1/9/2013         1         9       2013           MESA
# 4         127875   1/9/2013         1         9       2013           MESA

# %% [markdown]
# # 1. Eliminacion de valores nulls

# %%
df_ventas_totales.isna().sum()
# Out:
# SEGMENTO            3
# TIPOVENTA           2
# PRODUCTO            0
# CANTIDADUNIDADES    6
# PRECIOVENTA         0
# IMPORTEVENTAS       0
# FECHAVENTA          0
# DIAVENTA            0
# MESVENTA            0
# ANIOVENTA           0
# NOMBREPRODUCTO      0
# dtype: int64

# %%
df_ventas_totales.dropna(subset=["CANTIDADUNIDADES","SEGMENTO","TIPOVENTA"], inplace = True)

# %%
df_ventas_totales.isna().sum()
# Out:
# SEGMENTO            0
# TIPOVENTA           0
# PRODUCTO            0
# CANTIDADUNIDADES    0
# PRECIOVENTA         0
# IMPORTEVENTAS       0
# FECHAVENTA          0
# DIAVENTA            0
# MESVENTA            0
# ANIOVENTA           0
# NOMBREPRODUCTO      0
# dtype: int64

# %%
df_ventas_totales.head()
# Out:
#       SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0     GOBIERNO      OnLine         1             330.0          125
# 4     GOBIERNO      OnLine         1            1023.0          125
# 5  EXPORTACION     MAILING         1             494.0          300
# 6      EMPRESA  SUCURSALES         1            2851.0            7
# 9  Exportacion      ONSITE         1             214.0          300
#
#    IMPORTEVENTAS FECHAVENTA  DIAVENTA  MESVENTA  ANIOVENTA NOMBREPRODUCTO
# 0           5000   1/9/2013         1         9       2013           mesa
# 4         127875   1/9/2013         1         9       2013           MESA
# 5         148200  1/10/2013         1        10       2013           MESA
# 6          19957  1/10/2013         1        10       2013           MESA
# 9          64200  1/10/2013         1        10       2013           MESA

# %% [markdown]
# # 2. Normalizacion de campos descriptivo

# %%
descrip_campos = list(df_ventas_totales.columns[df_ventas_totales.dtypes == "object"])
descrip_campos.remove("FECHAVENTA")
print(descrip_campos)
# Out:
# ['SEGMENTO', 'TIPOVENTA', 'NOMBREPRODUCTO']

# %%
for col in descrip_campos:
    df_ventas_totales[col] = df_ventas_totales[col].apply(lambda x: x.title())

# %%
print(f"Segmentos {df_ventas_totales['SEGMENTO'].unique()}")
print(f"TipoVenta {df_ventas_totales['TIPOVENTA'].unique()}")
print(f"NombreProducto {df_ventas_totales['NOMBREPRODUCTO'].unique()}")
# Out:
# Segmentos ['Gobierno' 'Exportacion' 'Empresa' 'Educacion' 'Personas']
# TipoVenta ['Online' 'Mailing' 'Sucursales' 'Onsite']
# NombreProducto ['Mesa' 'Tv' 'Sillon' 'Silla' 'Cocina' 'Lavarropa']

# %% [markdown]
# # 3. Recalcular el valor importe ventas

# %%
df_ventas_totales["IMPORTEVENTAS"] = df_ventas_totales["CANTIDADUNIDADES"] * df_ventas_totales["PRECIOVENTA"]

# %%
df_ventas_totales.head()
# Out:
#       SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0     Gobierno      Online         1             330.0          125
# 4     Gobierno      Online         1            1023.0          125
# 5  Exportacion     Mailing         1             494.0          300
# 6      Empresa  Sucursales         1            2851.0            7
# 9  Exportacion      Onsite         1             214.0          300
#
#    IMPORTEVENTAS FECHAVENTA  DIAVENTA  MESVENTA  ANIOVENTA NOMBREPRODUCTO
# 0        41250.0   1/9/2013         1         9       2013           Mesa
# 4       127875.0   1/9/2013         1         9       2013           Mesa
# 5       148200.0  1/10/2013         1        10       2013           Mesa
# 6        19957.0  1/10/2013         1        10       2013           Mesa
# 9        64200.0  1/10/2013         1        10       2013           Mesa

# %% [markdown]
# # 4. Borrar Fecha Ventas

# %%
df_ventas_totales.drop(columns=["FECHAVENTA"],inplace=True)

# %%
df_ventas_totales.head()
# Out:
#       SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0     Gobierno      Online         1             330.0          125
# 4     Gobierno      Online         1            1023.0          125
# 5  Exportacion     Mailing         1             494.0          300
# 6      Empresa  Sucursales         1            2851.0            7
# 9  Exportacion      Onsite         1             214.0          300
#
#    IMPORTEVENTAS  DIAVENTA  MESVENTA  ANIOVENTA NOMBREPRODUCTO
# 0        41250.0         1         9       2013           Mesa
# 4       127875.0         1         9       2013           Mesa
# 5       148200.0         1        10       2013           Mesa
# 6        19957.0         1        10       2013           Mesa
# 9        64200.0         1        10       2013           Mesa

# %% [markdown]
# ### Reinicio de index

# %%
df_ventas_totales.reset_index(inplace=True)
df_ventas_totales.drop(columns=["index"],inplace = True)
df_ventas_totales.head()
# Out:
#       SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0     Gobierno      Online         1             330.0          125
# 1     Gobierno      Online         1            1023.0          125
# 2  Exportacion     Mailing         1             494.0          300
# 3      Empresa  Sucursales         1            2851.0            7
# 4  Exportacion      Onsite         1             214.0          300
#
#    IMPORTEVENTAS  DIAVENTA  MESVENTA  ANIOVENTA NOMBREPRODUCTO
# 0        41250.0         1         9       2013           Mesa
# 1       127875.0         1         9       2013           Mesa
# 2       148200.0         1        10       2013           Mesa
# 3        19957.0         1        10       2013           Mesa
# 4        64200.0         1        10       2013           Mesa

# %% [markdown]
# # 5. Archivo productos
#
# codigo de producto,nombre y total de ventas (group by)
# 	(agrupa por codigo de producto y nombre con suma de campo <importe ventas> para todas las ventas del producto)

# %%
df_productos = df_ventas_totales.groupby(["PRODUCTO","NOMBREPRODUCTO"]).sum("IMPORTEVENTAS")

# %%
df_productos = df_productos["IMPORTEVENTAS"]

# %%
df_productos.to_csv("PRODUCTOS_LucianoMoreno.csv",sep=';')

# %% [markdown]
# # 6. Archivo Ventas
# 	SEGMENTO
# 	TIPO VENTA
# 	PRODUCTO
# 	CANTIDAD UNIDADES
# 	PRECIO VENTA
# 	IMPORTE VENTAS
# 	DIA VENTA
# 	MES VENTA
# 	ANIO VENTA

# %%
df_ventas_totales.head()
# Out:
#       SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0     Gobierno      Online         1             330.0          125
# 1     Gobierno      Online         1            1023.0          125
# 2  Exportacion     Mailing         1             494.0          300
# 3      Empresa  Sucursales         1            2851.0            7
# 4  Exportacion      Onsite         1             214.0          300
#
#    IMPORTEVENTAS  DIAVENTA  MESVENTA  ANIOVENTA NOMBREPRODUCTO
# 0        41250.0         1         9       2013           Mesa
# 1       127875.0         1         9       2013           Mesa
# 2       148200.0         1        10       2013           Mesa
# 3        19957.0         1        10       2013           Mesa
# 4        64200.0         1        10       2013           Mesa

# %%
df_ventas = df_ventas_totales.drop(columns=["NOMBREPRODUCTO"])

# %%
df_ventas.head()
# Out:
#       SEGMENTO   TIPOVENTA  PRODUCTO  CANTIDADUNIDADES  PRECIOVENTA  \
# 0     Gobierno      Online         1             330.0          125
# 1     Gobierno      Online         1            1023.0          125
# 2  Exportacion     Mailing         1             494.0          300
# 3      Empresa  Sucursales         1            2851.0            7
# 4  Exportacion      Onsite         1             214.0          300
#
#    IMPORTEVENTAS  DIAVENTA  MESVENTA  ANIOVENTA
# 0        41250.0         1         9       2013
# 1       127875.0         1         9       2013
# 2       148200.0         1        10       2013
# 3        19957.0         1        10       2013
# 4        64200.0         1        10       2013

# %%
df_ventas.to_csv("VENTAS_LucianoMoreno.csv",sep=';')
