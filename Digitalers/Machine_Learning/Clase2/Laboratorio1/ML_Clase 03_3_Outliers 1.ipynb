# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set()

# %%
np.random.seed(50)
n = 950 # para generar datos sin outliers ponemos n = 1000
datos_normales = np.random.normal(5,2, size = n)#centro, desviacion standard, tamaño
datos_out = np.random.normal(12,1, size = 1000 - n)

# %%
sns.distplot(datos_normales)
sns.distplot(datos_out)

# %%
datos = np.concatenate((datos_normales, datos_out))

# %%
sns.distplot(datos)

# %%
sns.boxplot(datos)

# %%
data = pd.DataFrame()
data['Datos'] = datos
data['Outlier'] = np.zeros(datos.size)
data.iloc[n:,1] = 1

# %%
data = data.sample(frac = 1,random_state = 42)
data.reset_index(drop = True, inplace = True)

# %%
data[data.Outlier == 1]
# Out:
#          Datos  Outlier
# 13   11.693137      1.0
# 27   12.908427      1.0
# 43   12.791002      1.0
# 86   12.633931      1.0
# 107  14.164157      1.0
# 112  13.358959      1.0
# 117  13.779203      1.0
# 133   9.914441      1.0
# 152  12.974068      1.0
# 173  10.475603      1.0
# 222  11.577990      1.0
# 231  10.587165      1.0
# 237  10.515333      1.0
# 251  10.519530      1.0
# 289  13.405094      1.0
# 388  12.166490      1.0
# 399  10.592049      1.0
# 442  12.983142      1.0
# 463  11.991518      1.0
# 475  12.788713      1.0
# 505  13.423837      1.0
# 508  12.436988      1.0
# 518  12.741820      1.0
# 561  11.357649      1.0
# 569  13.294824      1.0
# 605  10.288091      1.0
# 616  11.909770      1.0
# 618  12.453601      1.0
# 627  11.352742      1.0
# 630  11.977158      1.0
# 637  11.808616      1.0
# 639  12.888558      1.0
# 643  11.438326      1.0
# 646  11.275841      1.0
# 654  12.227685      1.0
# 657  12.321738      1.0
# 662  13.613645      1.0
# ...

# %%
# data.to_csv('../DataSets/Outliers_Data_1.csv', columns = ['Datos'], index = False)
data.to_csv('../DataSets/Outliers_Data_2.csv', columns = ['Datos'], index = False)
