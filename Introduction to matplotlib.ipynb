# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/lucho/Desktop/Programacion/Python/Linkedin Data Science/base_datos_2008.csv", nrows = 100000)

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# Aca vemos los unicos dos casos que aparecen en esta columna y cuantas veces se repiten
data = np.unique(df.Cancelled, return_counts = True)
data
# Out:
# (array([0, 1], dtype=int64), array([98858,  1142], dtype=int64))

# %% [markdown]
# # Grafico de tortas

# %%
# Hacemos un grafico de torta sin modificar la estetica
plt.pie(x = data[1],
       labels = data[0])
plt.show()

# %%
# Hacemos un grafico de torta modificando la estetica
plt.pie(x = data[1],
       labels = data[0],
       colors = ["red","green"],
       shadow = True,
       startangle = 90,
       radius = 2)
plt.show()

# %%
# llamamos a la funcion con 1000000 de rows la desordenamos y agarramos una muestra de 100
np.random.seed(0)
df = pd.read_csv("C:/Users/lucho/Desktop/Programacion/Python/Linkedin Data Science/base_datos_2008.csv", nrows = 1000000)
df = df.sample(frac = 1).head(100)

# %%
df
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 157105  2008      1          11          5    615.0         615    955.0
# 374554  2008      1          29          2   1340.0        1345   2050.0
# 688694  2008      2          28          4   1354.0        1350   1444.0
# 265381  2008      1           8          2    938.0         940   1110.0
# 955415  2008      2          25          1   1411.0        1411   1621.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 567152  2008      1           6          7   1642.0        1625   1959.0
# 474312  2008      1          10          4   2102.0        2104   2232.0
# 611862  2008      2           4          1    605.0         605    603.0
# 591853  2008      1           4          5   1754.0        1759   2010.0
# 151774  2008      1           3          4   1145.0        1110   1332.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
# Hacemos un grafico de burbuja sin modificar la estetica
plt.scatter(x = df.DayofMonth, y = df.ArrDelay, s = df.Distance)

# %%
# Hacemos un grafico de torta modificando la estetica
plt.scatter(x = df.DayofMonth,
            y = df.ArrDelay,
            s = df.Distance,
           alpha = .3,
           c = df.DayOfWeek.isin([6,7]))
plt.title("Retrasos en EEUU")
plt.xlabel( "Dia del Mes")
plt.ylabel( "Retraso al llegar")
plt.ylim([0,150])
plt.xticks([0,15,30])
plt.text(x = 28, y = 120, s = "Mi Vuelo" )
plt.show()

# %% [markdown]
# # Etiquetas y legendas

# %%
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/lucho/Desktop/Programacion/Python/Linkedin Data Science/base_datos_2008.csv", nrows = 100000)
data = np.unique(df.DayOfWeek, return_counts = True)
labs = ["Lun","Mar","Mie","Jue","Vie","Sab","Dom"]
data
# Out:
# (array([1, 2, 3, 4, 5, 6, 7], dtype=int64),
#  array([14519, 14710, 14694, 17079, 14517, 11285, 13196], dtype=int64))

# %%
# Grafico de barras sin modificacion
plt.pie(x = data[1],
       labels = data[0],
       radius = 1.5,
       colors = ["Red","Green","Orange","Blue","Gray","Pink","Black"],
       startangle = 90)
plt.show()

# %%
# Gradico de barras modificando todos los datos
plt.pie(x = data[1],
       #labels = labs,
       radius = 1,
       colors = sns.color_palette("hls",7),
        explode = (0,0,0,0.2,0,0,0.1),
        autopct = "%1.1f%%",
        startangle = 90)
plt.legend(loc = "upper right", labels = labs)
plt.show()

# %%
# Creamos un grafico de barras con seaborn
plt = sns.barplot(x = labs, y = data[1])
plt.set(xlabel = "Dia de la semana", ylabel = "Numero de vuelos")
# Out:
# [Text(0.5, 0, 'Dia de la semana'), Text(0, 0.5, 'Numero de vuelos')]

# %% [markdown]
# # Graficos para series temporales

# %%
import datetime
import time

# %%
#Creamos una variable que contenga solos los vuelos que tengan origen en PHX, HOU, IND
df = pd.read_csv("C:/Users/lucho/Desktop/Programacion/Python/Linkedin Data Science/base_datos_2008.csv")
df2 = df[df["Origin"].isin(["PHX","HOU","IND"])]
df = df.head(500000)

# %%
# Lo que estamos haciendo es itterar por cada valor del df y que nos devuelva el año mes y dia del año
times = []
for i in np.arange(len(df)):
    times.append(datetime.datetime(year = 2008, month = df.loc[i,"Month"], day = df.loc[i,"DayofMonth"]))

# %%
times[50000]
# Out:
# datetime.datetime(2008, 1, 18, 0, 0)

# %%
df["Time"] = times
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 0        2225            WN        335  ...     8.0          0
# 1        1000            WN       3231  ...    10.0          0
# 2         750            WN        448  ...    17.0          0
# 3        1100            WN       1746  ...     7.0          0
# 4        1925            WN       3920  ...    10.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 0               NaN         0           NaN           NaN      NaN
# ...

# %%
# Agrupamos por dia y calculculamos la media del ArrDelay y DepDelat
data = df.groupby(by = ["Time"], as_index = False)["DepDelay","ArrDelay"].mean()
data.head()
# Out:
# <ipython-input-21-636314ada91b>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data = df.groupby(by = ["Time"], as_index = False)["DepDelay","ArrDelay"].mean()
#         Time   DepDelay   ArrDelay
# 0 2008-01-01  20.545599  20.999240
# 1 2008-01-02  23.324222  22.131194
# 2 2008-01-03  16.697759  14.479569
# 3 2008-01-04  14.058087  11.851733
# 4 2008-01-05  18.381555  17.138031

# %%
sns.lineplot(x = data["Time"], y= data["DepDelay"])
# Out:
# <AxesSubplot:xlabel='Time', ylabel='DepDelay'>

# %%
data = df.groupby(by=["Time"])["DepDelay","ArrDelay"].mean()
data.head()
# Out:
# <ipython-input-23-6f5686dfc3c8>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data = df.groupby(by=["Time"])["DepDelay","ArrDelay"].mean()
#              DepDelay   ArrDelay
# Time
# 2008-01-01  20.545599  20.999240
# 2008-01-02  23.324222  22.131194
# 2008-01-03  16.697759  14.479569
# 2008-01-04  14.058087  11.851733
# 2008-01-05  18.381555  17.138031

# %%
sns.lineplot(data = data)
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
# Lo que estamos haciendo es itterar por cada valor del df y que nos devuelva el año mes y dia del año para el segunda df
times = []
for i in df2.index:
    times.append(datetime.datetime(year = 2008, month = df2.loc[i,"Month"], day = df2.loc[i,"DayofMonth"]))
df2["Time"] = times

# %%
df2.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
# 5  2008      1           3          4   1940.0        1915   2121.0
# 6  2008      1           3          4   1937.0        1830   2037.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 2         750            WN        448  ...    17.0          0
# 3        1100            WN       1746  ...     7.0          0
# 4        1925            WN       3920  ...    10.0          0
# 5        2110            WN        378  ...    10.0          0
# 6        1940            WN        509  ...     7.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 2               NaN         0           NaN           NaN      NaN
# ...

# %%
sns.set(rc = {"figure.figsize": (15,10)})
sns.lineplot(x = "Time",y ="ArrDelay", hue = "Origin", data = df2)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='ArrDelay'>

# %% [markdown]
# # Histograma y boxplot

# %%
df = pd.read_csv("C:/Users/lucho/Desktop/Programacion/Python/Linkedin Data Science/base_datos_2008.csv")

# %%
df.dropna(inplace = True, subset = ["ArrDelay","DepDelay", "Distance"])

# %%
sns.displot(df["Distance"])

# %%
sns.displot(df["Distance"], kde = False, bins = 100)

# %%
sns.kdeplot(df["ArrDelay"])
sns.kdeplot(df["DepDelay"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-07df6e8a5439> in <module>
#       1 sns.kdeplot(df["ArrDelay"])
#       2 sns.kdeplot(df["DepDelay"])
# ----> 3 plt.xlim([-300, 300])
#
# AttributeError: 'AxesSubplot' object has no attribute 'xlim'

# %%
df2 = df[df["Origin"].isin(["PHX","HOU","IND"])].sample(frac = 1).head(500)

# %%
sns.boxplot(x="DepDelay", y= "Origin", data = df2)
# Out:
# <AxesSubplot:xlabel='DepDelay', ylabel='Origin'>
