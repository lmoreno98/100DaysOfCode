# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ---
# ## Exercise 1-5:
# 1
#
# Install and use Seaborn to generate the views for this section (pip install seaborn);
#
# Load the attached Iris dataset in this lesson.
#
# Remove the Id column;
#
# Use the countplot () function to show the frequency of the three Iris species in the dataset.
#
# 2
#
# Make a scatter plot to show the relation between 'SepalLengthCm' and 'SepalWidthCm';
#
# Make a scatter plot to show the relation between 'PetalLengthCm' and 'PetalWidthCm'.
#
# 3
#
# Make a histogram of the dataset's features (exclusive Species column).
#
# 4
#
# Boxplot the features of the dataset (exclusive Species column).
#
# 5
#
# Make a heatmap of the dataset's features (exclusive Species column);
#
# Make a pairplot to analyze the correlation between the variables in the dataset.

# %%
# 1
iris = pd.read_html("https://github.com/lmoreno98/100DaysOfCode/blob/main/Python_Practice_guide/Datasets/Iris_seaborn.csv")[0].drop(columns=["Unnamed: 0","Id"])
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.countplot(iris["Species"])
plt.title('Frequency of the three species in the Iris Dataset')
plt.ylabel('Frequency')
plt.ylim(0,80)
# Out:
# C:\Users\lucho\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 80.0)

# %%
# 2
sns.scatterplot(x= "SepalLengthCm", y = "SepalWidthCm", data= iris, hue="Species")
plt.title("Sepal lenght - Sepal Width")
# Out:
# Text(0.5, 1.0, 'Sepal lenght - Sepal Width')

# %%
sns.scatterplot(x= "PetalLengthCm", y = "PetalWidthCm", data= iris, hue="Species")
plt.title("Petal lenght - Petal Width")
# Out:
# Text(0.5, 1.0, 'Petal lenght - Petal Width')

# %%
# 3
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1, figsize = (10, 10))
sns.histplot(x = 'SepalLengthCm', data = iris, ax = ax1)
ax1.set(title = 'Sepal Length histogram', ylabel = 'Frequency')

sns.histplot(x = 'SepalWidthCm', data = iris, ax = ax2)
ax2.set(title = 'Sepal Width histogram', ylabel = 'Frequency')

sns.histplot(x = 'PetalLengthCm', data = iris, ax = ax3)
ax3.set(title = 'Petal Length histogram', ylabel = 'Frequency')

sns.histplot(x = 'PetalWidthCm', data = iris, ax = ax4)
ax4.set(title = 'Petal Width histogram', ylabel = 'Frequency')

plt.tight_layout(pad = 2)

# %%
# 4
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1, figsize = (10, 10))
sns.boxplot(x = 'SepalLengthCm', data = iris, ax = ax1)
ax1.set(title = 'Sepal Length histogram', ylabel = 'Frequency')

sns.boxplot(x = 'SepalWidthCm', data = iris, ax = ax2)
ax2.set(title = 'Sepal Width histogram', ylabel = 'Frequency')

sns.boxplot(x = 'PetalLengthCm', data = iris, ax = ax3)
ax3.set(title = 'Petal Length histogram', ylabel = 'Frequency')

sns.boxplot(x = 'PetalWidthCm', data = iris, ax = ax4)
ax4.set(title = 'Petal Width histogram', ylabel = 'Frequency')

plt.tight_layout(pad = 2)

# %%
# 5
corr = iris.corr()
sns.heatmap(corr, cmap="Blues", annot= True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(iris)

# %% [markdown]
# ---
# ## Exercise 6:
#
#     Use the code below to load the dataset tips with Seaborn (which presents data about the tip paid by customers, the total bill amount, as well as other information);
#
#     import seaborn as sns
#     tips = sns.load_dataset('tips')
#
#     Present the descriptive statistics of the dataset with the describe () function;
#
#     Show the dataset columns;
#
#     Show the shape of the dataset;
#
#     Check the unique values of the sex, smoker, day and time columns;
#
#     Present the proportion between men and women;
#
#     Present the ratio between smokers and non-smokers;

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.shape
# Out:
# (244, 7)

# %%
categ_tips = tips.select_dtypes("category")

# %%
for col in categ_tips.columns:
    print(f"Unique values for {col}: {tips[col].unique()}")
# Out:
# Unique values for sex: ['Female', 'Male']
# Categories (2, object): ['Female', 'Male']
# Unique values for smoker: ['No', 'Yes']
# Categories (2, object): ['No', 'Yes']
# Unique values for day: ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']
# Unique values for time: ['Dinner', 'Lunch']
# Categories (2, object): ['Dinner', 'Lunch']

# %%
tips["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# ---
# ## Exercise 7
#
#     Use the sns.countplot() function to build a chart with categorical data from the dataset.
# ---
# ## Exercise 8
#
#     Use the sns.scatterplot() function to view the relationship between the 'total_bill' and 'tip' variables;
#
#     Use the sns.scatterplot() function to visualize the relationship between the 'total_bill' and 'tip' variables and use the hue argument to color each point with the 'sex' variable.
# ---
# ## Exercise 9
#
#     Use the sns.relplot() function to view the relationship between the 'tip' and 'size' variables and also use the hue argument to color each point with the 'smoker' variable.
# ---
# ## Exercise 10
#
#     Build a boxplot for the quantitative variables in the dataset.
# ---
# ## Exercise 11
#
#     Use the sns.histplot() function to view the distribution of the 'tip' and 'total_bill' variables.

# %%
# 7
for col in categ_tips.columns:
    sns.countplot(col,data = tips)
    plt.show()
# Out:
# C:\Users\lucho\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 8
sns.scatterplot(x = "total_bill", y = "tip", data = tips, hue = "sex")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# 9
sns.relplot(x = "tip", y = "size", data = tips, hue = "smoker")

# %%
#10
sns.boxplot(data = tips)
# Out:
# <AxesSubplot:>

# %%
# 11
sns.histplot( data = tips, x = "tip")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot( data = tips, x = "total_bill")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ---
# ## Exercise 12
#
#     Build a heatmap to visualize the degree of relationship between the variables.
# ---
# ## Exercise 13
#
#     Make a pairplot to analyze the relationship between the variables in the dataset.
# ---
# ## Exercise 14
#
#     Use the sns.lmplot() function to visualize the relationship between 'total_bill' and 'tip', fitting a linear regression line.
# ---
# ## Exercise 15
#
#     Use the sns.lmplot() function to visualize the relationship between 'total_bill' and 'tip', adjusting a linear regression line and also use the hue argument to color each point with the variable 'smoker'.

# %%
#12
corr = tips.corr()
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot:>

# %%
#13
sns.pairplot(tips)

# %%
#14
sns.lmplot(x = "total_bill", y = "tip",data = tips, hue = "smoker")

# %% [markdown]
# ---
# Based on the DataFrame below, answer:
#
#
#     import pandas as pd
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#     import numpy as np
#
#     np.random.seed(20)
#     n = 2_000  #size
#     data = {
#         'A': np.random.normal(loc = 100, scale = 1, size = n),
#         'B': np.random.normal(loc = 100, scale = 2, size = n),
#         'C': np.random.normal(loc = 100, scale = 5, size = n),
#         'D': np.random.lognormal(mean = 2, sigma = 1.1, size = n),
#         'E': np.random.lognormal(mean = 2, sigma = 1.2, size = n),
#         'F': np.random.lognormal(mean = 2, sigma = 1.3, size = n),
#         'G': np.random.randn(n),
#         'H': np.random.binomial(n = 10, p = 0.8, size = n)
#     }
#
#     df = pd.DataFrame(data)
#
# ---
# ## Exercise 16
#
#     Use the sns.kdeplot() function to demonstrate in a single plot the distribution of the variables 'A', 'B' and 'C', which follow a normal distribution.
# ---
# ## Exercise 17
#
#     Use the sns.kdeplot() function to demonstrate in a single plot the distribution of the variables 'D', 'E' and 'F', which follow a lognormal distribution.
# ----
# ## Exercise 18
#
#     Use the sns.joinplot() function to demonstrate the relationship between variables 'A' and 'B', showing their respective distributions. Repeat the same procedure for variables 'D' and 'F'.

# %%
np.random.seed(20)
n = 2_000  #size
data = {
    'A': np.random.normal(loc = 100, scale = 1, size = n),
    'B': np.random.normal(loc = 100, scale = 2, size = n),
    'C': np.random.normal(loc = 100, scale = 5, size = n),
    'D': np.random.lognormal(mean = 2, sigma = 1.1, size = n),
    'E': np.random.lognormal(mean = 2, sigma = 1.2, size = n),
    'F': np.random.lognormal(mean = 2, sigma = 1.3, size = n),
    'G': np.random.randn(n),
    'H': np.random.binomial(n = 10, p = 0.8, size = n)
}

df = pd.DataFrame(data)

# %%
# 16
sns.kdeplot(x="A", data = df)
sns.kdeplot(x="B", data = df)
sns.kdeplot(x="C", data = df)
plt.legend(["A","B","C"])

# %%
#17
sns.kdeplot(x="D", data = df)
sns.kdeplot(x="E", data = df)
sns.kdeplot(x="F", data = df)
plt.legend(["D","E","F"])

# %%
sns.jointplot(x = "A", y = "B", data = df)

# %%
sns.jointplot(x = "D", y = "F", data = df)

# %% [markdown]
# ---
# ## Exercise 19
#
#     Make an individual histogram for the variables in the dataset.
# ---
# ## Exercise 20
#
#     Design a violinplot for the variables 'G' and 'H', respectively. This graph consists of a combination of the boxplot and the kernel density estimate (kde).

# %%
#19
for col in df.columns:
    sns.histplot(data = df[col])
    plt.show()

# %%
#20
sns.violinplot(x = "G", data = df)
# Out:
# <AxesSubplot:xlabel='G'>

# %%
sns.violinplot(x = "H", data = df)
# Out:
# <AxesSubplot:xlabel='H'>

# %% [markdown]
# ----
# Load the attached dataset in this class and then do:
#
#     import pandas as pd
#     series = pd.read_csv( 'Airline_passengers.csv' , header=0, index_col=0, parse_dates=True,
#     squeeze=True)
#
# ## Exercise 21
#
#     Present the descriptive statistics of the time series with the describe () function;
#
#     Show the shape of the dataset.
#
# ## Exercise 22
#
#     Make a line graph to demonstrate the evolution of the variable 'Airline-passengers' over time.
#
# ## Exercise 23
#
#     Make a boxplot characterize the variable 'Airline-passengers'.
#
# ## Exercise 24
#
#     Make a histogram and a kde plot.
#
# ## Exercise 25
#
#     Import the lag_plot function and apply the time series (this function generates a lag plot for time series.)
#
#     from pandas.plotting import lag_plot

# %%
series = pd.read_csv( 'Datasets/Airline_passengers.csv' , header=0, index_col=0, parse_dates=True,
squeeze=True)

# %%
#21
series.describe()
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: Airline_passengers, dtype: float64

# %%
series.shape
# Out:
# (144,)

# %%
# 22
sns.lineplot(data = series)
plt.grid(linestyle = "--", alpha = 0.6)

# %%
#23
sns.boxplot(data = series)
# Out:
# <AxesSubplot:>

# %%
#24
sns.kdeplot(data = series)
# Out:
# <AxesSubplot:xlabel='Airline_passengers', ylabel='Density'>

# %%
sns.histplot(data = series)
# Out:
# <AxesSubplot:xlabel='Airline_passengers', ylabel='Count'>

# %%
#25
from pandas.plotting import lag_plot

# %%
lag_plot(series = series)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>
