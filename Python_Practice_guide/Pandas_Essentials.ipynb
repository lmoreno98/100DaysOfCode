# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exercise 1:
# A Series (one-dimensional array) from the Pandas library can be created using the constructor:
#
#
#     pd.Series (data, index, dtype, copy)
#
# Then, we can create Series objects from arrays, dictionaries, scalars and iterables. Based on this information, answer the following questions.
#
#
# a) From the list below create an object of type Series.
#
#
#     data = ['a', 'b', 'c', 'd']
#
#
# Expected result:
#
#
#     0    a
#     1    b
#     2    c
#     3    d
#     dtype: object
#
#
# b) From the previous list, obtain:
#
#
#     10    a
#     11    b
#     12    c
#     13    d
#     dtype: object
#
#
# Tip: Change the index argument.
#
#
# c) Obtain the Series below:
#
#
#     0    10
#     1    10
#     2    10
#     3    10
#     dtype: int64
#
#
# d) From the array,
#
#
#     import numpy as np
#     array = np.arange(10,20,2)
#
#
# Obtain the Series below:
#
#
#     1    10.0
#     2    12.0
#     3    14.0
#     4    16.0
#     5    18.0
#     dtype: float64

# %%
data =['A','B','C','D']
ex1A = pd.Series(data)
ex1A
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# dtype: object

# %%
index = [10,11,12,13]
ex1B = pd.Series(data,index)
ex1B
# Out:
# 10    A
# 11    B
# 12    C
# 13    D
# dtype: object

# %%
data_10 = np.ones(4,int)*10
ex1C = pd.Series(data_10)
ex1C
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# dtype: int32

# %%
data = np.arange(10,19,2)
index = np.arange(1,6)
ex1D = pd.Series(data,index)
ex1D
# Out:
# 1    10
# 2    12
# 3    14
# 4    16
# 5    18
# dtype: int32

# %% [markdown]
# ---
# ## Exercise 2:
# A Series (one-dimensional array) from the Pandas library can be created using the constructor:
#
#
#     pd.Series (data, index, dtype, copy)
#
#
# Then, we can create Series objects from arrays, dictionaries, scalars and iterables. Based on this information, answer the following questions.
#
#
# a) From the list below create an object of type Series.
#
#     data = ['k','w','z','y']
#
#
# Expected result:
#
#
#     0    k
#     1    w
#     2    z
#     3    y
#     dtype: object
#
#
# b) From the dictionary below create an object of type Series.
#
#
#     dic = {'a':10,'b':30,'c':15,'d':12}
#
#
# Expected result:
#
#
#     a    10
#     b    30
#     c    15
#     d    12
#     dtype: int64
#
#
# c) Convert to a list the Series objects created previously.
#
#
# Tip: use the pandas to_list() method.
#
#
# d) Convert Series objects created in letters a) and b) to DataFrame. Enter a name for the columns. Use the pd.DataFrame() constructor.
#
#
# Expected Results:
#
#
#     	Letters
#     0	k
#     1	w
#     2	z
#     3	y
#
#
#         Values
#     a	10
#     b	30
#     c	15
#     d	12

# %%
ex2A = ['k','w','z','y']
pd.Series(ex2A)
# Out:
# 0    k
# 1    w
# 2    z
# 3    y
# dtype: object

# %%
ex2B = {'a':10,'b':30,'c':15,'d':12}
pd.Series(ex2B)
# Out:
# a    10
# b    30
# c    15
# d    12
# dtype: int64

# %%
ex2C = pd.Series(ex2B).to_list()
ex2C
# Out:
# [10, 30, 15, 12]

# %%
pd.DataFrame((ex2A), columns=['Letters'])
# Out:
#   Letters
# 0       k
# 1       w
# 2       z
# 3       y

# %%
pd.DataFrame((ex2C), columns=['Numbers'])
# Out:
#    Numbers
# 0       10
# 1       30
# 2       15
# 3       12

# %% [markdown]
# ---
# ## Exercise 3:
# Use the NumPy library to create the following Series object.
#
#
#     25     1.0
#     26     3.0
#     27     5.0
#     28     7.0
#     29     9.0
#     30    11.0
#     31    13.0
#     32    15.0
#     33    17.0
#     34    19.0
#     35    21.0
#     36    23.0
#     37    25.0
#     38    27.0
#     39    29.0
#     40    31.0
#     41    33.0
#     42    35.0
#     43    37.0
#     44    39.0
#     45    41.0
#     46    43.0
#     47    45.0
#     48    47.0
#     49    49.0
#     Name: Serie, dtype: float64

# %%
pd.Series(data = np.arange(1,50,2),index = np.arange(25,50), dtype= float)
# Out:
# 25     1.0
# 26     3.0
# 27     5.0
# 28     7.0
# 29     9.0
# 30    11.0
# 31    13.0
# 32    15.0
# 33    17.0
# 34    19.0
# 35    21.0
# 36    23.0
# 37    25.0
# 38    27.0
# 39    29.0
# 40    31.0
# 41    33.0
# 42    35.0
# 43    37.0
# 44    39.0
# 45    41.0
# 46    43.0
# 47    45.0
# 48    47.0
# 49    49.0
# dtype: float64

# %% [markdown]
# ---
# ## Exercise 4:
# a) From the list below, create an object of type Series with pandas.
#
#
#     data = ['ITUB4', 'BBDC4', 'BBAS3', 'BPAC11', 'SANB11']
#
#
# Expected result:
#
#     1     ITUB4
#     2     BBDC4
#     3     BBAS3
#     4    BPAC11
#     5    SANB11
#     Name: Prices, dtype: object
#
#
# b) Convert the Series to a dictionary.
#
# c) Convert the Series to a list.
#
# d) Convert the Series to a numpy.ndarray object.

# %%
data = ['ITUB4', 'BBDC4', 'BBAS3', 'BPAC11', 'SANB11']
ex4A = pd.Series(data)
ex4A
# Out:
# 0     ITUB4
# 1     BBDC4
# 2     BBAS3
# 3    BPAC11
# 4    SANB11
# dtype: object

# %%
ex4B = ex4A.to_dict()
ex4B
# Out:
# {0: 'ITUB4', 1: 'BBDC4', 2: 'BBAS3', 3: 'BPAC11', 4: 'SANB11'}

# %%
ex4C = ex4A.to_list()
ex4C
# Out:
# ['ITUB4', 'BBDC4', 'BBAS3', 'BPAC11', 'SANB11']

# %%
ex4D = ex4A.to_numpy()
ex4D
# Out:
# array(['ITUB4', 'BBDC4', 'BBAS3', 'BPAC11', 'SANB11'], dtype=object)

# %% [markdown]
# ---
# ## Exercise 5:
# a) From the dictionary below, create an object of type Series and store it in a variable. Then, convert the created object to a list. Finally, create a DataFrame with the available data.
#
#
#     data = {
#         'ABEV3':12.85,
#         'AZUL4':22.55,
#         'BTOW3':115.08,
#         'RENT3':49.03,
#         'JBSS3':24.41,
#         }
#
#
# b) Add the new values to the created Series:
#
#
#     RAIL3: 18.93
#     SUZB3: 48.19
#     MGLU3: 25.59

# %%
data = {
    'ABEV3':12.85,
    'AZUL4':22.55,
    'BTOW3':115.08,
    'RENT3':49.03,
    'JBSS3':24.41,
    }
ex5A_0 = pd.Series(data)
ex5A_0
# Out:
# ABEV3     12.85
# AZUL4     22.55
# BTOW3    115.08
# RENT3     49.03
# JBSS3     24.41
# dtype: float64

# %%
ex5A_1 = ex5A_0.to_list()
ex5A_1
# Out:
# [12.85, 22.55, 115.08, 49.03, 24.41]

# %%
ex5A_2 = pd.DataFrame(ex5A_1, columns=['Prices'])
ex5A_2
# Out:
#    Prices
# 0   12.85
# 1   22.55
# 2  115.08
# 3   49.03
# 4   24.41

# %%
ex5A_0['RAIL3'] =  18.93
ex5A_0['SUZB3'] =  48.19
ex5A_0['MGLU3'] =  25.59
ex5A_0
# Out:
# ABEV3     12.85
# AZUL4     22.55
# BTOW3    115.08
# RENT3     49.03
# JBSS3     24.41
# RAIL3     18.93
# SUZB3     48.19
# MGLU3     25.59
# dtype: float64

# %% [markdown]
# ---
# ## Exercise 6:
# Add the three new values to the Series below.
#
#
#     PETR4:22,97;
#     NTCO3:50,60;
#     TIMP3:14,82.
#
#
#     data = {
#         'ABEV3':12.85,
#         'AZUL4':22.55,
#         'BTOW3':115.08,
#         'RENT3':49.03,
#         'JBSS3':24.41,
#         }
#
#     serie = pd.Series(data)
#
#
# Expected result:
#
#
#     ABEV3     12.85
#     AZUL4     22.55
#     BTOW3    115.08
#     RENT3     49.03
#     JBSS3     24.41
#     PETR4     22.97
#     NTCO3     50.60
#     TIMP3     14.82
#     dtype: float64

# %%
data = {
    'ABEV3':12.85,
    'AZUL4':22.55,
    'BTOW3':115.08,
    'RENT3':49.03,
    'JBSS3':24.41,
    } 

ex6A = pd.Series(data)
ex6A
# Out:
# ABEV3     12.85
# AZUL4     22.55
# BTOW3    115.08
# RENT3     49.03
# JBSS3     24.41
# dtype: float64

# %%
ex6A['PETR4'] = 22.97
ex6A['NTCO3'] = 50.60
ex6A['TIMP3'] = 14.82
ex6A
# Out:
# ABEV3     12.85
# AZUL4     22.55
# BTOW3    115.08
# RENT3     49.03
# JBSS3     24.41
# PETR4     22.97
# NTCO3     50.60
# TIMP3     14.82
# dtype: float64

# %% [markdown]
# ---
# ## Exercise 7:
# Create Series A and B below :
#
# A:
#
#     A     1
#     B     3
#     C     5
#     D     7
#     E     9
#     F    11
#     G    13
#     H    15
#     I    17
#     J    19
#     dtype: int64
#
# B:
#
#     F     5
#     G    10
#     H    15
#     I    20
#     J    25
#     K    30
#     L    35
#     M    40
#     N    45
#     dtype: int64

# %%
pd.Series(data = np.arange(1,20,2), index= list('ABCDEFGHIJ'))
# Out:
# A     1
# B     3
# C     5
# D     7
# E     9
# F    11
# G    13
# H    15
# I    17
# J    19
# dtype: int32

# %%
pd.Series(data = np.arange(5,46,5), index= list('FGHIJKLMN'))
# Out:
# F     5
# G    10
# H    15
# I    20
# J    25
# K    30
# L    35
# M    40
# N    45
# dtype: int32

# %% [markdown]
# ---
# ## Exercise 8:
# Build the Series object below and use the .plot () method to generate a graph of the created object.
#
#
#     2020    2197
#     2010    1728
#     2000    1331
#     1990    1000
#     1980     729
#     1970     512
#     1960     343
#     1950     216
#     1940     125
#     1930      64
#     1920      27
#     1910       8
#     1900       1
#     Name: Crescimento no tempo, dtype: int64
#
#
# The growth rate over time:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-13_02-00-44-85e527b94d681d66935773a6e2c80226.png>

# %%
ex8 = pd.Series(data = [i**3 for i in range(1, 14)][::-1], index= np.arange(2020,1899,-10))
ex8
# Out:
# 2020    2197
# 2010    1728
# 2000    1331
# 1990    1000
# 1980     729
# 1970     512
# 1960     343
# 1950     216
# 1940     125
# 1930      64
# 1920      27
# 1910       8
# 1900       1
# dtype: int64

# %%
ex8.plot()
plt.xlabel("Years")
plt.ylabel("Grow")
plt.title("Grow Rate Over Time")
# Out:
# Text(0.5, 1.0, 'Grow Rate Over Time')

# %% [markdown]
# ---
# ## Exercise 9:
# Based on the Series below,
#
#
#     import pandas as pd
#     s = pd.Series([1, 2, 3, 4, 5, 6], index = ['a', 'b', 'c', 'd', 'e', 'f'])
#
#
# Do:
#
# a) show the first element;
#
# b) show the third element;
#
# c) show the first three elements;
#
# d) show the last three elements;
#
# e) show the last element.

# %%
ex9 = pd.Series([1, 2, 3, 4, 5, 6], index = ['a', 'b', 'c', 'd', 'e', 'f'])

# %%
print(f"First Element: {ex9.iloc[0]}")
print(f"Third Element: {ex9.iloc[2]}")
print(f"Last Element: {ex9.iloc[-1]}")
# Out:
# First Element: 1
# Third Element: 3
# Last Element: 6

# %%
print(f"""First Three Element: 
{ex9.iloc[0:3]}""")
# Out:
# First Three Element:
# a    1
# b    2
# c    3
# dtype: int64

# %%
print(f"""First Three Element: 
{ex9.iloc[-3:]}""")
# Out:
# First Three Element:
# d    4
# e    5
# f    6
# dtype: int64

# %% [markdown]
# ---
# ## Exercise 10:
# Create a Series and access the following attributes: axes, dtype, empty, ndim, size and values.
#
#
# Being that:
#
#     pd.Series(). axes: returns a list with the Series indexes;
#
#     pd.Series(). empty: returns a Boolean value, informing whether the object is empty or not;
#
#     pd.Series(). ndim: returns the number of dimensions of the object;
#
#     pd.Series(). size: returns the size of the Series;
#
#     pd.Series(). values: returns the data in a NumPy object (ndarray)

# %%
ex10 = pd.Series([1, 2, 3, 4, 5, 6], index = ['a', 'b', 'c', 'd', 'e', 'f'])

# %%
ex10.axes
# Out:
# [Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')]

# %%
ex10.empty
# Out:
# False

# %%
ex10.ndim
# Out:
# 1

# %%
ex10.size
# Out:
# 6

# %%
ex10.values
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %% [markdown]
# ---
# ## Exercise 11:
# Build the DataFrame below and store it in a variable.
#
#
#     	A
#     0	10
#     1	22
#     2	3
#     3	11
#     4	17
#     5	22
#     6	9
#     7	4
#     8	29
#     9	31

# %%
ex11 = pd.DataFrame(data = {'A':[10,22,3,11,17,22,9,4,29,31]})
ex11
# Out:
#     A
# 0  10
# 1  22
# 2   3
# 3  11
# 4  17
# 5  22
# 6   9
# 7   4
# 8  29
# 9  31

# %% [markdown]
# ---
# ## Exercise 12:
# Build an object of type DataFrame with the structure below and store it in a variable. Put the data in a Python dictionary.
#
#
#         A  B    C
#     0  11  1  130
#     1  33  2  144
#     2  11  3  111
#     3  -1  4  104
#     4   0  5  199

# %%
data = {'A':[11,33,11,-1,0],
        'B':np.arange(1,6),
        'C':[130,144,111,104,199]}

# %%
pd.DataFrame(data = data)
# Out:
#     A  B    C
# 0  11  1  130
# 1  33  2  144
# 2  11  3  111
# 3  -1  4  104
# 4   0  5  199

# %% [markdown]
# ---
# ## Exercise 13:
# Build an object of type DataFrame with the structure below and store it in a variable. Note that column A corresponds to all even numbers between [1.20] and column B to the cube of each odd number in the same range.
#
# Put the data in a Python dictionary and use List Comprehension to build the columns.
#
#
#         A     B
#     1    2     1
#     2    4    27
#     3    6   125
#     4    8   343
#     5   10   729
#     6   12  1331
#     7   14  2197
#     8   16  3375
#     9   18  4913
#     10  20  6859

# %%
dic = {'A' : np.arange(2,21,2),
    'B' : [i**3 for i in range(1, 20,2)]}

# %%
ex13 = pd.DataFrame(data = dic)
ex13
# Out:
#     A     B
# 0   2     1
# 1   4    27
# 2   6   125
# 3   8   343
# 4  10   729
# 5  12  1331
# 6  14  2197
# 7  16  3375
# 8  18  4913
# 9  20  6859

# %% [markdown]
# ---
# ## Exercise 14:
# For the previous DataFrame, plot a line graph and add a new column with the square of each odd number in the range [1.20]. To do so, use: df.plot().

# %%
ex14A = ex13
ex14B = [i**2 for i in range(1, 20,2)]
ex14A["C"] = ex14B
ex14A.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---
# ## Exercise 15:
# Build the DataFrame below that represents the prices registered for four products between 2010 to 2019, generate a visualization with the method previously seen. Use NumPy to generate prices (random numbers), according to a normal distribution of mean 800 and standard deviation 30, for the respective columns. To do so, use the np.random.normal() function.
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-05-18_13-21-15-836e91f4a2ba3da09dd1619fa582d1fa.png>
# Expected visualization:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-05-18_13-23-05-f809d890d745f624710ae533624a1009.png>

# %%
ex15 = pd.DataFrame(data = np.random.normal(800,30,(10,4)), index = np.arange(2010,2020), columns=list("ABCD"))
ex15.columns.name = "Products"
ex15
# Out:
# Products           A           B           C           D
# 2010      813.506014  793.695353  779.040475  816.935012
# 2011      803.499406  798.075858  751.121927  801.141180
# 2012      855.590365  773.619250  772.340678  766.606109
# 2013      793.923776  754.667339  739.635420  862.822477
# 2014      754.954376  803.527474  802.409490  749.658596
# 2015      797.049846  754.629689  782.257363  785.062382
# 2016      806.243803  799.522831  820.635626  796.565632
# 2017      908.296088  789.522913  791.244815  856.136057
# 2018      822.800627  754.753846  766.787658  814.622033
# 2019      839.398861  748.357301  773.853938  770.269769

# %%
ex15.plot()
plt.xlabel("Years")
# Out:
# Text(0.5, 0, 'Years')

# %% [markdown]
# ---
# ## Exercise 16:
# Build a DataFrame type object with the structure below, which represents a price, quantity, and total cost table for a set of products.
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-12_19-06-09-cfe8264b4f70f930424fd9404194b39d.png>

# %%
ex16_dic = {"Price": [20.3,31.2,44.7,30.5,19.8,11.2,15.7,17.3], 
            "Unit": [10,33,45,51,11,8,91,8],
            "Total Cost" : [100.00,568.70,205.20,507.10,250.12,55.30,1579.00,130]}
index = ["Product 1","Product 2","Product 3","Product 4","Product 5","Product 6","Product 7","Product 8"]
ex16  = pd.DataFrame(ex16_dic, index)
ex16
# Out:
#            Price  Unit  Total Cost
# Product 1   20.3    10      100.00
# Product 2   31.2    33      568.70
# Product 3   44.7    45      205.20
# Product 4   30.5    51      507.10
# Product 5   19.8    11      250.12
# Product 6   11.2     8       55.30
# Product 7   15.7    91     1579.00
# Product 8   17.3     8      130.00

# %% [markdown]
# ---
# ## Exercise 17:
# Considering the previous exercise: (1) add a new column 'Total Revenue' (TR) to the DataFrame, which corresponds to the product between the price (p) and the quantity (q), that is, TR = p x q; (2) add a new column 'Total Profit' (TP), which corresponds to the difference between Total Revenue and Total Cost (TC), that is, TP = TR - TC.
#
# Expected result:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-12_19-11-47-b3a3f469edfa3c719031122234062964.png>

# %%
ex17 = ex16
ex17["Total Revenue"] = ex17["Price"]*ex17["Unit"]
ex17["Total Profit"] = ex17["Total Revenue"] - ex17["Total Cost"] 
ex17
# Out:
#            Price  Unit  Total Cost  Total Revenue  Total Profit
# Product 1   20.3    10      100.00          203.0        103.00
# Product 2   31.2    33      568.70         1029.6        460.90
# Product 3   44.7    45      205.20         2011.5       1806.30
# Product 4   30.5    51      507.10         1555.5       1048.40
# Product 5   19.8    11      250.12          217.8        -32.32
# Product 6   11.2     8       55.30           89.6         34.30
# Product 7   15.7    91     1579.00         1428.7       -150.30
# Product 8   17.3     8      130.00          138.4          8.40

# %% [markdown]
# ---
# ## Exercise 18:
# Build a DataFrame type object with the structure below. Use np.random.random () to generate random numbers.
#
#
# Expected result:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-21_17-50-43-2c319851d1b31b83e7f51adeeda3e278.png>

# %%
ex18 = np.random.random((10,5))
ex18A = pd.DataFrame(ex18, index = range(1,11), columns = list("ABCDE"))
ex18A
# Out:
#            A         B         C         D         E
# 1   0.362111  0.167451  0.338389  0.230374  0.376603
# 2   0.897780  0.913957  0.112760  0.141676  0.819642
# 3   0.735138  0.542668  0.700421  0.529747  0.381744
# 4   0.706296  0.630287  0.860450  0.979727  0.882499
# 5   0.136903  0.315646  0.863579  0.040374  0.629647
# 6   0.564607  0.188646  0.586290  0.539570  0.831722
# 7   0.005803  0.142264  0.389610  0.755784  0.319038
# 8   0.587522  0.366383  0.275002  0.010459  0.309040
# 9   0.960644  0.139091  0.743593  0.779210  0.894079
# 10  0.115855  0.074288  0.488608  0.758472  0.876290

# %% [markdown]
# ---
# ## Exercise 19:
# Use a nested dict data structure to create the following DataFrame.
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-12_19-15-16-bb1569ba2eeee1ffc9d2687a080918c2.png>

# %%
ex19_dic = {
    "Product1": {2008:7, 2009:9, 2010:10, 2011:15, 2012:50, 2013:47},
    "Product2": {2008:14 ,2009:13, 2010:7, 2011:13, 2012:77, 2013:94},
    "Product3": {2008:5, 2009:11, 2010:3, 2011:45, 2012:21, 2013:33},
    "Product4": {2008:4, 2009:2, 2010:3, 2011:45, 2012:21, 2013:33}
}
ex19 = pd.DataFrame(ex19_dic)
ex19.index.name = "Year"
ex19.columns.name = "Products"
ex19
# Out:
# Products  Product1  Product2  Product3  Product4
# Year
# 2008             7        14         5         4
# 2009             9        13        11         2
# 2010            10         7         3         3
# 2011            15        13        45        45
# 2012            50        77        21        21
# 2013            47        94        33        33

# %% [markdown]
# ---
# ## Exercise 20:
# Build the DataFrame below and perform the following operations:
#     data = {
#         'Customers': ['Adrian', 'Carl', 'Eliza', 'Albert', 'Fred', 'Oswald', 'Grace', 'John'],
#         'Age': [36, 39, 33, 32, 27, 35, 28, 18],
#         'Rating': [6.2, 2.17, 6.56, 8.32, 9.15, 1.34, 0.57, 1.66]
#     }
#
#
# a) Read the first 5 lines with the df.head() method;
#
# b) Read the first 3 lines with the df.head method(n = 10);
#
# c) Read the last 5 lines with the df.tail() method;
#
# d) Read the last 2 lines with the df.tail method(n = 2).
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-12_19-19-23-ccd4b3fbe498fdf188ca1c4ddb5967a4.png>

# %%
ex20 = { 'Customers': ['Adrian', 'Carl', 'Eliza', 'Albert', 'Fred', 'Oswald', 'Grace', 'John'], 
        'Age': [36, 39, 33, 32, 27, 35, 28, 18], 
        'Rating': [6.2, 2.17, 6.56, 8.32, 9.15, 1.34, 0.57, 1.66] }
ex20A = pd.DataFrame(ex20)
ex20A
# Out:
#   Customers  Age  Rating
# 0    Adrian   36    6.20
# 1      Carl   39    2.17
# 2     Eliza   33    6.56
# 3    Albert   32    8.32
# 4      Fred   27    9.15
# 5    Oswald   35    1.34
# 6     Grace   28    0.57
# 7      John   18    1.66

# %%
print(" ----------A-------------")
ex20A.head()
# Out:
#  ----------A-------------
#   Customers  Age  Rating
# 0    Adrian   36    6.20
# 1      Carl   39    2.17
# 2     Eliza   33    6.56
# 3    Albert   32    8.32
# 4      Fred   27    9.15

# %%
print(" ----------B-------------")
ex20A.head(n = 3)
# Out:
#  ----------B-------------
#   Customers  Age  Rating
# 0    Adrian   36    6.20
# 1      Carl   39    2.17
# 2     Eliza   33    6.56

# %%
print(" ----------C-------------")
ex20A.tail()
# Out:
#  ----------C-------------
#   Customers  Age  Rating
# 3    Albert   32    8.32
# 4      Fred   27    9.15
# 5    Oswald   35    1.34
# 6     Grace   28    0.57
# 7      John   18    1.66

# %%
print(" ----------D-------------")
ex20A.tail(n = 2)
# Out:
#  ----------D-------------
#   Customers  Age  Rating
# 6     Grace   28    0.57
# 7      John   18    1.66

# %% [markdown]
# ---
# ## Exercise 21:
# Build the DataFrame below. Use List Comprehension to create the 'Result' column (Tip: 'Yes' if Score>=7). Use the info() function to display information from the dataset.
#
#     names = ['Oswald', 'Richard', 'Victor', 'Walter', 'Ronald', 'Rebecca', 'Maurice', 'Margaret']
#     scores = [7, 8 , 4.7, 10, 9.5, 6, 5, 7.7]
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-12_19-23-55-0d570195e5e20738a6bd7e5ff067227a.png>

# %%
ex21_names = ['Oswald', 'Richard', 'Victor', 'Walter', 'Ronald', 'Rebecca', 'Maurice', 'Margaret']
ex21_scores = [7, 8 , 4.7, 10, 9.5, 6, 5, 7.7]
ex21_result = ["Yes" if score >= 7 else "No" for score in ex21_scores]

# %%
ex21_A = {"Name": ex21_names,
         "Score": ex21_scores,
         "Result": ex21_result}
ex21_B = pd.DataFrame(ex21_A)
ex21_B
# Out:
#        Name  Score Result
# 0    Oswald    7.0    Yes
# 1   Richard    8.0    Yes
# 2    Victor    4.7     No
# 3    Walter   10.0    Yes
# 4    Ronald    9.5    Yes
# 5   Rebecca    6.0     No
# 6   Maurice    5.0     No
# 7  Margaret    7.7    Yes

# %% [markdown]
# ---
# ## Exercise 22:
# Based on the previous exercise:
#
#
# a) apply the describe () method to obtain descriptive statistics from the numerical columns;
#
# b) print the student who got the highest score;
#
# c) print the student who got the minimum score;
#
# d) select only approved students and store them in a variable.

# %%
ex21_B.describe()
# Out:
#           Score
# count   8.00000
# mean    7.23750
# std     1.94858
# min     4.70000
# 25%     5.75000
# 50%     7.35000
# 75%     8.37500
# max    10.00000

# %%
ex21_B.max()
# Out:
# Name      Walter
# Score       10.0
# Result       Yes
# dtype: object

# %%
ex21_B.min()
# Out:
# Name      Margaret
# Score          4.7
# Result          No
# dtype: object

# %%
ex22 = ex21_B["Result"] == "Yes"

# %%
ex21_B.loc[ex22]
# Out:
#        Name  Score Result
# 0    Oswald    7.0    Yes
# 1   Richard    8.0    Yes
# 3    Walter   10.0    Yes
# 4    Ronald    9.5    Yes
# 7  Margaret    7.7    Yes

# %% [markdown]
# ---
# ## Exercise 23:
# Based on the DataFrame below,
#
#
#     import pandas as pd
#     import numpy as np
#
#     data = np.random.uniform(low = 0, high = 5, size = (100,5))
#     df = pd.DataFrame(data,
#                       index = range(1,data.shape[0]+1),
#                       columns = list('ABCDE'))
#
#
# Show on-screen the following information:
#
# a) number of lines;
#
# b) number of columns;
#
# c) shape;
#
# d) the total number of elements;
#
# e) number of dimensions;
#
# f) dataset information with the info () function;
#
# g) the data type  (dtype) of each column;
#
# h) descriptive statistics for each column.

# %%
data = np.random.uniform(low = 0, high = 5, size = (100,5))
ex23 = pd.DataFrame(data, 
                  index = range(1,data.shape[0]+1), 
                  columns = list('ABCDE'))  
ex23
# Out:
#             A         B         C         D         E
# 1    4.337916  1.625247  2.819600  0.225246  2.650906
# 2    1.800781  2.095484  2.378380  4.221479  3.821416
# 3    2.365214  4.819873  3.260768  0.722650  3.563933
# 4    1.390187  1.615766  0.435280  0.494529  0.879496
# 5    1.991542  4.889088  3.753521  2.857289  3.881265
# ..        ...       ...       ...       ...       ...
# 96   3.746195  0.415806  3.255901  4.756527  1.364392
# 97   0.508375  3.181828  0.512533  4.369554  1.416424
# 98   1.837411  4.578303  2.212780  2.871396  4.816871
# 99   0.363255  1.569696  4.309574  0.147744  4.906613
# 100  0.231979  4.068301  2.625170  0.752499  0.052855
#
# [100 rows x 5 columns]

# %%
print(f"Number of lines: {len(ex23.index)}")
print(f"Number of columns: {len(ex23.columns)}")
print(f"Shape: {ex23.shape}")
print(f"Total number of elements: {ex23.size}")
print(f"Number of dimensions: {ex23.ndim}")
print(f"Data types: {ex23.dtypes}")
# Out:
# Number of lines: 100
# Number of columns: 5
# Shape: (100, 5)
# Total number of elements: 500
# Number of dimensions: 2
# Data types: A    float64
# B    float64
# C    float64
# D    float64
# E    float64
# dtype: object

# %%
ex23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 1 to 100
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       100 non-null    float64
#  1   B       100 non-null    float64
#  2   C       100 non-null    float64
#  3   D       100 non-null    float64
#  4   E       100 non-null    float64
# dtypes: float64(5)
# memory usage: 4.0 KB

# %%
ex23.describe()
# Out:
#                 A           B           C           D           E
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     2.198677    2.351080    2.671571    2.461248    2.716671
# std      1.378887    1.502952    1.352976    1.477051    1.563334
# min      0.002618    0.026433    0.031942    0.055615    0.047268
# 25%      1.008434    1.075670    1.654260    1.023804    1.403588
# 50%      2.093255    2.165212    2.576702    2.453468    2.638767
# 75%      3.353215    3.531403    3.758020    3.798342    4.227121
# max      4.994206    4.889088    4.881890    4.988253    4.988945

# %% [markdown]
# ---
# ## Exercise 24:
# Build the DataFrame below and do:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-21_19-02-05-c2eb6aed7d8a635cea547dc4c496693f.png>
#
# a) display the data type of each column;
#
# b) convert the dtype of columns 'C' and 'E' to category (Tip: df['columns'].astype('category'));
#
# c) select and print only the columns from the category type (Tip: df.select_dtypes('category'));
#
# d) select and print only the columns from the bool type;
#
# f) select and print only the numeric columns;
#
# g) print descriptive statistics for each column, including categorical columns.
#
#
#     dic = {
#         'A': [11, 3, 7, 99, 100, 130, 150],
#         'B': [1.2, 0.5, 1.2, 3.2, 0.9, 1.7, 9.5],
#         'C': ['A', 'Z', 'W', 'K', 'A', 'Z', 'Z'],
#         'D': [True, False, True, False, True, False, True],
#         'E': ['A', 'A', 'B', 'B', 'A', 'A', 'B'],
#         'F': [True, True, False, False, True, False, True],}

# %%
ex24_dic = {
    'A': [11, 3, 7, 99, 100, 130, 150],
    'B': [1.2, 0.5, 1.2, 3.2, 0.9, 1.7, 9.5],
    'C': ['A', 'Z', 'W', 'K', 'A', 'Z', 'Z'],
    'D': [True, False, True, False, True, False, True],    
    'E': ['A', 'A', 'B', 'B', 'A', 'A', 'B'],
    'F': [True, True, False, False, True, False, True],}
ex24 = pd.DataFrame(ex24_dic, index = range(10,71,10), columns=list("ABCDEF"))
ex24
# Out:
#       A    B  C      D  E      F
# 10   11  1.2  A   True  A   True
# 20    3  0.5  Z  False  A   True
# 30    7  1.2  W   True  B  False
# 40   99  3.2  K  False  B  False
# 50  100  0.9  A   True  A   True
# 60  130  1.7  Z  False  A  False
# 70  150  9.5  Z   True  B   True

# %%
ex24.dtypes
# Out:
# A      int64
# B    float64
# C     object
# D       bool
# E     object
# F       bool
# dtype: object

# %%
ex24[["C","E"]] = ex24[["C","E"]].astype("category")
ex24.dtypes
# Out:
# A       int64
# B     float64
# C    category
# D        bool
# E    category
# F        bool
# dtype: object

# %%
ex24.select_dtypes('category')
# Out:
#     C  E
# 10  A  A
# 20  Z  A
# 30  W  B
# 40  K  B
# 50  A  A
# 60  Z  A
# 70  Z  B

# %%
ex24.select_dtypes('bool')
# Out:
#         D      F
# 10   True   True
# 20  False   True
# 30   True  False
# 40  False  False
# 50   True   True
# 60  False  False
# 70   True   True

# %%
ex24.select_dtypes(["int64","float64"])
# Out:
#       A    B
# 10   11  1.2
# 20    3  0.5
# 30    7  1.2
# 40   99  3.2
# 50  100  0.9
# 60  130  1.7
# 70  150  9.5

# %%
ex24.describe(include= "all")
# Out:
#                  A         B    C     D    E     F
# count     7.000000  7.000000    7     7    7     7
# unique         NaN       NaN    4     2    2     2
# top            NaN       NaN    Z  True    A  True
# freq           NaN       NaN    3     4    4     4
# mean     71.428571  2.600000  NaN   NaN  NaN   NaN
# std      62.803549  3.162278  NaN   NaN  NaN   NaN
# min       3.000000  0.500000  NaN   NaN  NaN   NaN
# 25%       9.000000  1.050000  NaN   NaN  NaN   NaN
# 50%      99.000000  1.200000  NaN   NaN  NaN   NaN
# 75%     115.000000  2.450000  NaN   NaN  NaN   NaN
# max     150.000000  9.500000  NaN   NaN  NaN   NaN

# %% [markdown]
# ---
# ## Ecercise 25:
# Build the DataFrame below. Use NumPy to construct the column data, with the np.random.normal() function, consider a distribution with a mean of 10 and a standard deviation of 0.5. Use List Comprehension to configure indexes and columns.
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-21_19-11-24-1f686ebebfcd9e467454b1a55a120c33.png>

# %%
ex25_data = np.random.normal(10,0.5,(10,10))
ex25_cols = list("ABCDEFGHIJ")
ex25_index = [col + str(i) for i, col in zip(range(1,11), ex25_cols)]

# %%
ex25 = pd.DataFrame(ex25_data,index= ex25_index, columns = ex25_cols)
ex25
# Out:
#              A          B          C          D          E          F  \
# A1    9.878786   9.902988   9.434257   9.415834   9.782724   9.518023
# B2    9.241134  10.385984   9.035133   9.891316   9.864672  10.289394
# C3   10.623463   9.570790   9.325431  10.232862  10.948326  10.202448
# D4    9.919599   9.781282   8.555251  10.037048  10.299163   9.697885
# E5    9.975248   9.519746  10.006650   9.875081  10.135986   9.960252
# F6   10.613585  10.154344  10.062252  10.211023  10.793413  10.151754
# G7   10.046716   9.699005  10.035913   8.937444  10.371642   9.696957
# H8    9.921543  10.516884   9.747734   9.654935  10.531057   9.701754
# I9    9.464350   9.433789   9.173143  10.789088  10.344313  10.527989
# J10   9.554897  10.224387   9.757456   9.902244   9.475947   9.210130
#
#              G          H          I          J
# A1   10.131216   9.421492   9.823883   9.714130
# B2   10.937266   9.412788  10.258911  10.475924
# C3   10.219970  10.350794  10.166156   9.890915
# ...

# %% [markdown]
# ---
# ## Exercise 26:
# Based on the following DataFrame obtain:
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-12_19-52-41-3919e1713b9f053e528703e34575c939.png>
#
# a) select the 'Name' column and store it in a variable;
#
# b) select the 'Result' column and store it in a variable;
#
# c) select and print the 'Name' and 'Result' columns;
#
# d) select the line 6 of the DataFrame;
#
# e) select the DataFrame lines 3 to 5.

# %%
ex26_names = ['Carl', 'Margaret', 'Maurice', 'Oscar', 'Peter', 'Oswald', 'Paul', 'Ronald']
ex26_scores = [7, 8 , 4.7, 10, 9.5, 6, 5, 7.7]
ex26_result = ["Yes" if score >= 7 else "No" for score in ex21_scores]
ex26_dic = {"Name": ex26_names,
         "Score": ex26_scores,
         "Result": ex26_result}
ex26 = pd.DataFrame(ex26_dic)
ex26
# Out:
#        Name  Score Result
# 0      Carl    7.0    Yes
# 1  Margaret    8.0    Yes
# 2   Maurice    4.7     No
# 3     Oscar   10.0    Yes
# 4     Peter    9.5    Yes
# 5    Oswald    6.0     No
# 6      Paul    5.0     No
# 7    Ronald    7.7    Yes

# %%
ex26A = ex26["Name"]
ex26A
# Out:
# 0        Carl
# 1    Margaret
# 2     Maurice
# 3       Oscar
# 4       Peter
# 5      Oswald
# 6        Paul
# 7      Ronald
# Name: Name, dtype: object

# %%
ex26B = ex26["Result"]
ex26B
# Out:
# 0    Yes
# 1    Yes
# 2     No
# 3    Yes
# 4    Yes
# 5     No
# 6     No
# 7    Yes
# Name: Result, dtype: object

# %%
ex26[["Name","Result"]]
# Out:
#        Name Result
# 0      Carl    Yes
# 1  Margaret    Yes
# 2   Maurice     No
# 3     Oscar    Yes
# 4     Peter    Yes
# 5    Oswald     No
# 6      Paul     No
# 7    Ronald    Yes

# %%
ex26.loc[5]
# Out:
# Name      Oswald
# Score        6.0
# Result        No
# Name: 5, dtype: object

# %%
ex26.loc[2:4]
# Out:
#       Name  Score Result
# 2  Maurice    4.7     No
# 3    Oscar   10.0    Yes
# 4    Peter    9.5    Yes

# %% [markdown]
# ---
# ## Exercise 27:
# Also based on the DataFramefrom the previous exercise:
#
#
# a) select the names 'Margaret', 'Maurice' and 'Oscar' and store them in a list;
#
# b) select the names 'Carl', 'Maurice', and 'Ronald' and store them in a list;
#
# c) select the name 'Carl';
#
# d) select the score 7.7.

# %%
ex26.loc[[1,2,3]]
# Out:
#        Name  Score Result
# 1  Margaret    8.0    Yes
# 2   Maurice    4.7     No
# 3     Oscar   10.0    Yes

# %%
ex26.loc[[0,2,7]]
# Out:
#       Name  Score Result
# 0     Carl    7.0    Yes
# 2  Maurice    4.7     No
# 7   Ronald    7.7    Yes

# %%
ex26.loc[0][0]
# Out:
# 'Carl'

# %%
ex26.loc[7][1]
# Out:
# 7.7

# %% [markdown]
# ---
# ## Exercise 28:
# Create the DataFrame below, which represents the profit of different brands in years of operation of a company. Use List Comprehension to build columns and indexes. To construct the values use np.random.seed(7), so the random values are the same as those defined here in this exercise.
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-13_02-09-14-faf23ba6e4a99d4d9e24c32025dca641.png>
# a) access the following attributes: columns, index, shape, and values;
#
# b) select the 'Brand A' and 'Brand C' columns, individually;
#
# c) show the descriptive statistics for each column with the describe () function;
#
# d) show information from the dataset with the info () function;
#
# e) show the data type of each column in the dataset;
#
# f) convert the data type of the columns to float;
#
# g) select the profit of the brands in year 1 (use the loc and iloc functions);
#
# h) select the profit for Brand C in years 1 and 3 (use the loc and iloc functions);
#
# i) select the profit for brands A, C, and D, in years 2 and 4 (use the loc and iloc functions);
#
# j) show the average profit of each brand in this time interval;
#
# l) show the average profit for all brands in each year.

# %%
data = [[48,5,26,4],[20,24,40,29],[15,24,9,26],[47,43,27,9]]
col_name = ["Brand " + chr(65+i) for i in range(4)] 
index_name = ["Year " + str(i) for i in range(1,5)]
ex28 = pd.DataFrame(data, columns= col_name, index = index_name)
ex28
# Out:
#         Brand A  Brand B  Brand C  Brand D
# Year 1       48        5       26        4
# Year 2       20       24       40       29
# Year 3       15       24        9       26
# Year 4       47       43       27        9

# %%
print("---------------- A ----------------")
print(f"Columns: {ex28.columns}")
print(f"index: {ex28.index}")
print(f"Shape: {ex28.shape}")
print(f"values: {ex28.values}")
print("---------------- B ----------------")
print(ex28["Brand A"])
print()
print(ex28["Brand C"])
# Out:
# ---------------- A ----------------
# Columns: Index(['Brand A', 'Brand B', 'Brand C', 'Brand D'], dtype='object')
# index: Index(['Year 1', 'Year 2', 'Year 3', 'Year 4'], dtype='object')
# Shape: (4, 4)
# values: [[48  5 26  4]
#  [20 24 40 29]
#  [15 24  9 26]
#  [47 43 27  9]]
# ---------------- B ----------------
# Year 1    48
# Year 2    20
# Year 3    15
# Year 4    47
# Name: Brand A, dtype: int64
#
# Year 1    26
# Year 2    40
# Year 3     9
# Year 4    27
# Name: Brand C, dtype: int64

# %%
print("---------------- C ----------------")
print(ex28.describe(include = "all"))
print("---------------- D ----------------")
ex28.info()
# Out:
# ---------------- C ----------------
#          Brand A    Brand B    Brand C    Brand D
# count   4.000000   4.000000   4.000000   4.000000
# mean   32.500000  24.000000  25.500000  17.000000
# std    17.445152  15.513435  12.714821  12.355835
# min    15.000000   5.000000   9.000000   4.000000
# 25%    18.750000  19.250000  21.750000   7.750000
# 50%    33.500000  24.000000  26.500000  17.500000
# 75%    47.250000  28.750000  30.250000  26.750000
# max    48.000000  43.000000  40.000000  29.000000
# ---------------- D ----------------
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Year 1 to Year 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Brand A  4 non-null      int64
#  1   Brand B  4 non-null      int64
#  2   Brand C  4 non-null      int64
#  3   Brand D  4 non-null      int64
# dtypes: int64(4)
# memory usage: 160.0+ bytes

# %%
print("---------------- E ----------------")
print(ex28.dtypes)
print("---------------- F ----------------")
ex28.astype("float64")
# Out:
# ---------------- E ----------------
# Brand A    int64
# Brand B    int64
# Brand C    int64
# Brand D    int64
# dtype: object
# ---------------- F ----------------
#         Brand A  Brand B  Brand C  Brand D
# Year 1     48.0      5.0     26.0      4.0
# Year 2     20.0     24.0     40.0     29.0
# Year 3     15.0     24.0      9.0     26.0
# Year 4     47.0     43.0     27.0      9.0

# %%
print("---------------- G ----------------")
print(ex28.iloc[0])
print("---------------- H ----------------")
print(ex28.iloc[[0,2],2])
# Out:
# ---------------- G ----------------
# Brand A    48
# Brand B     5
# Brand C    26
# Brand D     4
# Name: Year 1, dtype: int64
# ---------------- H ----------------
# Year 1    26
# Year 3     9
# Name: Brand C, dtype: int64

# %%
print("---------------- I ----------------")
print(ex28.iloc[[1,3],[0,2,3]])
print("---------------- J ----------------")
print(ex28.mean())
# Out:
# ---------------- I ----------------
#         Brand A  Brand C  Brand D
# Year 2       20       40       29
# Year 4       47       27        9
# ---------------- J ----------------
# Brand A    32.5
# Brand B    24.0
# Brand C    25.5
# Brand D    17.0
# dtype: float64

# %%
print("---------------- L ----------------")
print(ex28.mean(axis = 1))
# Out:
# ---------------- L ----------------
# Year 1    20.75
# Year 2    28.25
# Year 3    18.50
# Year 4    31.50
# dtype: float64

# %% [markdown]
# ---
# ## Exercise 29:
# Based on the previous dataset:
#
#
# a) create a column for 'Brand E', which recorded the following profits for the respective years: 70, 77, 81, 103;
#
# b) rename the column names to, respectively: 'A', 'B', 'C', 'D', 'E';
#
# c) rename the DataFrame index to respectively: 'YEAR 1', 'YEAR 2', 'YEAR 3', 'YEAR 4';
#
# d) replace the 'Brand C' profit value ('C' in the new notation) in YEAR 2 from 40 to 37.

# %%
ex29 = ex28

# %%
ex29["Brand E"] = [70,77,81,103]
ex29
# Out:
#         Brand A  Brand B  Brand C  Brand D  Brand E
# Year 1       48        5       26        4       70
# Year 2       20       24       40       29       77
# Year 3       15       24        9       26       81
# Year 4       47       43       27        9      103

# %%
ex29.rename(columns = {"Brand A": "A",
                       "Brand B":"B",
                       "Brand C": "C",
                       "Brand D":"D",
                       "Brand E": "E"}, inplace= True)
ex29
# Out:
#          A   B   C   D    E
# Year 1  48   5  26   4   70
# Year 2  20  24  40  29   77
# Year 3  15  24   9  26   81
# Year 4  47  43  27   9  103

# %%
ex29.rename(index = str.upper,inplace= True)
ex29
# Out:
#          A   B   C   D    E
# YEAR 1  48   5  26   4   70
# YEAR 2  20  24  40  29   77
# YEAR 3  15  24   9  26   81
# YEAR 4  47  43  27   9  103

# %%
ex29["C"]["YEAR 2"] = 37
ex29
# Out:
#          A   B   C   D    E
# YEAR 1  48   5  26   4   70
# YEAR 2  20  24  37  29   77
# YEAR 3  15  24   9  26   81
# YEAR 4  47  43  27   9  103

# %% [markdown]
# ---
# ## Exercise 30:
# Check if the DataFrame values are contained in the list ['f', 'b', 'z']. Tip: df.isin().
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-22_00-52-57-8a4bba1b4c3be4ca10d454fda8a3f407.png>
#
#     dic = {
#         'A': ['a', 'b', 'c'],
#         'B': ['f', 'g', 'w'],
#         'C': ['z', 'k', 'm']}

# %%
dic = {
    'A': ['a', 'b', 'c'],
    'B': ['f', 'g', 'w'],
    'C': ['z', 'k', 'm']}

ex30 = pd.DataFrame(dic)
ex30
# Out:
#    A  B  C
# 0  a  f  z
# 1  b  g  k
# 2  c  w  m

# %%
ex30.isin(["f","b","z"])
# Out:
#        A      B      C
# 0  False   True   True
# 1   True  False  False
# 2  False  False  False

# %% [markdown]
# ---
# ## Exercise 31:
# Delete the columns 'B', 'Z' e 'W' from the DataFrame below.
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-22_01-26-50-cb77a297f1ef868ad1a36dc0562d27fc.png>
#
#     data = {
#         'A': ['z', 'k' ,'m'],
#         'B': ['j', 'n' , 'o'],
#         'C': ['o', 'p', 'k'],
#         'Z': ['i', 'j' ,'k'],
#         'W': ['p', 'k', 'u']
#     }

# %%
data = {
    'A': ['z', 'k' ,'m'],
    'B': ['j', 'n' , 'o'],
    'C': ['o', 'p', 'k'],
    'Z': ['i', 'j' ,'k'],
    'W': ['p', 'k', 'u']
}
ex31 = pd.DataFrame(data)
ex31B = pd.DataFrame(data)
ex31
# Out:
#    A  B  C  Z  W
# 0  z  j  o  i  p
# 1  k  n  p  j  k
# 2  m  o  k  k  u

# %%
ex31.iloc[:][["A","C"]]
# Out:
#    A  C
# 0  z  o
# 1  k  p
# 2  m  k

# %%
ex31B.drop(labels = ['B', 'Z', 'W'], axis = 1, inplace = True)
ex31B
# Out:
#    A  C
# 0  z  o
# 1  k  p
# 2  m  k

# %% [markdown]
# ---
# ## Exercise 32:
# Build the DataFrame below and get:
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-13_02-25-25-c74f12a57c57498bb6c2533c5386b594.png>
# a) Descriptive statistics of the notes;
#
# b) create a new column to store the students' final average;
#
# c) create a new column to inform whether the student has been approved or not, based on the final score (the grade must be greater than or equal to 7); to do so, create a function and use the pandas apply () method.
#
#
#
#     students = [
#         'Naomi', 'Yumi','Hinata',
#         'Hana', 'Akira', 'Yuki',
#         'Yudi', 'Sakura', 'Sasuke',
#         'Hiroshi', 'Ken', 'Emi']
#     mathematics = [1, 3, 1, 3, 4, 3, 1, 9, 5, 9, 1, 2]
#     chemestry = [6, 5, 5, 8, 6, 6, 5, 3, 7, 8, 6, 4]
#     biology = [8, 7, 9, 9, 7, 7, 8, 7, 7, 7, 7, 9]
#     economy = [3, 2, 7, 8, 9, 9, 5, 9, 8, 6, 7, 9]

# %%
students = [
    'Naomi', 'Yumi','Hinata',
    'Hana', 'Akira', 'Yuki',
    'Yudi', 'Sakura', 'Sasuke',
    'Hiroshi', 'Ken', 'Emi']
mathematics = [1, 3, 1, 3, 4, 3, 1, 9, 5, 9, 1, 2]
chemestry = [6, 5, 5, 8, 6, 6, 5, 3, 7, 8, 6, 4]
biology = [8, 7, 9, 9, 7, 7, 8, 7, 7, 7, 7, 9]
economy = [3, 2, 7, 8, 9, 9, 5, 9, 8, 6, 7, 9]
data = {
    "Students" : students,
    "Mathematics" : mathematics,
    "Chemestry" : chemestry,
    "Biology" : biology,
    "Economy" : economy,
}
ex32 = pd.DataFrame(data, index = range(1,13))
ex32
# Out:
#    Students  Mathematics  Chemestry  Biology  Economy
# 1     Naomi            1          6        8        3
# 2      Yumi            3          5        7        2
# 3    Hinata            1          5        9        7
# 4      Hana            3          8        9        8
# 5     Akira            4          6        7        9
# 6      Yuki            3          6        7        9
# 7      Yudi            1          5        8        5
# 8    Sakura            9          3        7        9
# 9    Sasuke            5          7        7        8
# 10  Hiroshi            9          8        7        6
# 11      Ken            1          6        7        7
# 12      Emi            2          4        9        9

# %%
ex32.describe()
# Out:
#        Mathematics  Chemestry    Biology    Economy
# count    12.000000  12.000000  12.000000  12.000000
# mean      3.500000   5.750000   7.666667   6.833333
# std       2.876235   1.484771   0.887625   2.405801
# min       1.000000   3.000000   7.000000   2.000000
# 25%       1.000000   5.000000   7.000000   5.750000
# 50%       3.000000   6.000000   7.000000   7.500000
# 75%       4.250000   6.250000   8.250000   9.000000
# max       9.000000   8.000000   9.000000   9.000000

# %%
ex32["Final Avg"] =  ex32.drop(["Students"], axis = 1).mean(axis = 1)

# %%
ex32
# Out:
#    Students  Mathematics  Chemestry  Biology  Economy  Final Avg
# 1     Naomi            1          6        8        3       4.50
# 2      Yumi            3          5        7        2       4.25
# 3    Hinata            1          5        9        7       5.50
# 4      Hana            3          8        9        8       7.00
# 5     Akira            4          6        7        9       6.50
# 6      Yuki            3          6        7        9       6.25
# 7      Yudi            1          5        8        5       4.75
# 8    Sakura            9          3        7        9       7.00
# 9    Sasuke            5          7        7        8       6.75
# 10  Hiroshi            9          8        7        6       7.50
# 11      Ken            1          6        7        7       5.25
# 12      Emi            2          4        9        9       6.00

# %%
def result(final_result):
    if final_result >= 7:
        return "Approved"
    else:
        return "Reproved"
ex32["Result"] = ex32["Final Avg"].apply(result)

# %%
ex32
# Out:
#    Students  Mathematics  Chemestry  Biology  Economy  Final Avg    Result
# 1     Naomi            1          6        8        3       4.50  Reproved
# 2      Yumi            3          5        7        2       4.25  Reproved
# 3    Hinata            1          5        9        7       5.50  Reproved
# 4      Hana            3          8        9        8       7.00  Approved
# 5     Akira            4          6        7        9       6.50  Reproved
# 6      Yuki            3          6        7        9       6.25  Reproved
# 7      Yudi            1          5        8        5       4.75  Reproved
# 8    Sakura            9          3        7        9       7.00  Approved
# 9    Sasuke            5          7        7        8       6.75  Reproved
# 10  Hiroshi            9          8        7        6       7.50  Approved
# 11      Ken            1          6        7        7       5.25  Reproved
# ...

# %% [markdown]
# ---
# ## Exercise 33:
# Based on the previous dataset, filter:
#
#
# a) students who had a math score greater than or equal to 7;
#
# b) students who scored less than 5 in Chemistry;
#
# c) students who scored 8 in Biology;
#
# d) students who scored in Economics other than 9;
#
# e) students who had a final average lower than 5;
#
# f) approved students.

# %%
ex33A = ex32.loc[:]["Mathematics"] >= 7
ex32.loc[ex33A]
# Out:
#    Students  Mathematics  Chemestry  Biology  Economy  Final Avg    Result
# 8    Sakura            9          3        7        9        7.0  Approved
# 10  Hiroshi            9          8        7        6        7.5  Approved

# %%
ex33A = ex32.loc[:]["Chemestry"] < 5
ex32.loc[ex33A]
# Out:
#    Students  Mathematics  Chemestry  Biology  Economy  Final Avg    Result
# 8    Sakura            9          3        7        9        7.0  Approved
# 12      Emi            2          4        9        9        6.0  Reproved

# %%
ex33A = ex32.loc[:]["Biology"] == 8
ex32.loc[ex33A]
# Out:
#   Students  Mathematics  Chemestry  Biology  Economy  Final Avg    Result
# 1    Naomi            1          6        8        3       4.50  Reproved
# 7     Yudi            1          5        8        5       4.75  Reproved

# %%
ex33A = ex32.loc[:]["Economy"] != 9
ex32.loc[ex33A]
# Out:
#    Students  Mathematics  Chemestry  Biology  Economy  Final Avg    Result
# 1     Naomi            1          6        8        3       4.50  Reproved
# 2      Yumi            3          5        7        2       4.25  Reproved
# 3    Hinata            1          5        9        7       5.50  Reproved
# 4      Hana            3          8        9        8       7.00  Approved
# 7      Yudi            1          5        8        5       4.75  Reproved
# 9    Sasuke            5          7        7        8       6.75  Reproved
# 10  Hiroshi            9          8        7        6       7.50  Approved
# 11      Ken            1          6        7        7       5.25  Reproved

# %%
ex33A = ex32.loc[:]["Final Avg"] < 5
ex32.loc[ex33A]
# Out:
#   Students  Mathematics  Chemestry  Biology  Economy  Final Avg    Result
# 1    Naomi            1          6        8        3       4.50  Reproved
# 2     Yumi            3          5        7        2       4.25  Reproved
# 7     Yudi            1          5        8        5       4.75  Reproved

# %%
ex33A = ex32.loc[:]["Result"] == "Approved"
ex32.loc[ex33A]
# Out:
#    Students  Mathematics  Chemestry  Biology  Economy  Final Avg    Result
# 4      Hana            3          8        9        8        7.0  Approved
# 8    Sakura            9          3        7        9        7.0  Approved
# 10  Hiroshi            9          8        7        6        7.5  Approved

# %% [markdown]
# ---
# ## Exercise 34:
# Use the query() function to obtain the filters from the previous exercise.

# %%
ex32.query("Mathematics >= 7")
# Out:
#    Students  Mathematics  Chemestry  Biology  Economy  Final Avg    Result
# 8    Sakura            9          3        7        9        7.0  Approved
# 10  Hiroshi            9          8        7        6        7.5  Approved

# %%
ex32.query("Chemestry < 5")
# Out:
#    Students  Mathematics  Chemestry  Biology  Economy  Final Avg    Result
# 8    Sakura            9          3        7        9        7.0  Approved
# 12      Emi            2          4        9        9        6.0  Reproved

# %%
ex32.query("Biology == 8")
# Out:
#   Students  Mathematics  Chemestry  Biology  Economy  Final Avg    Result
# 1    Naomi            1          6        8        3       4.50  Reproved
# 7     Yudi            1          5        8        5       4.75  Reproved

# %%
ex32.query("Economy != 9")
# Out:
#    Students  Mathematics  Chemestry  Biology  Economy  Final Avg    Result
# 1     Naomi            1          6        8        3       4.50  Reproved
# 2      Yumi            3          5        7        2       4.25  Reproved
# 3    Hinata            1          5        9        7       5.50  Reproved
# 4      Hana            3          8        9        8       7.00  Approved
# 7      Yudi            1          5        8        5       4.75  Reproved
# 9    Sasuke            5          7        7        8       6.75  Reproved
# 10  Hiroshi            9          8        7        6       7.50  Approved
# 11      Ken            1          6        7        7       5.25  Reproved

# %%
ex32.query("`Final Avg` < 5")
# Out:
#   Students  Mathematics  Chemestry  Biology  Economy  Final Avg    Result
# 1    Naomi            1          6        8        3       4.50  Reproved
# 2     Yumi            3          5        7        2       4.25  Reproved
# 7     Yudi            1          5        8        5       4.75  Reproved

# %%
ex32.query("Result == 'Approved'")
# Out:
#    Students  Mathematics  Chemestry  Biology  Economy  Final Avg    Result
# 4      Hana            3          8        9        8        7.0  Approved
# 8    Sakura            9          3        7        9        7.0  Approved
# 10  Hiroshi            9          8        7        6        7.5  Approved

# %% [markdown]
# ---
# ## Exercise 35:
# Build the following DataFrame using nested dictionaries. This exercise will be used below.
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-12_20-34-48-058a0a59eb3c078537461c44acc27e30.png>

# %%
ex35 = {
    'Company A': {'2018': 90, '2019': 76, '2020': 109},
    'Company B': {'2018': 33.0, '2019': np.nan, '2020': 13.0},
    'Company C': {'2018': 273.0, '2019': 33.0, '2020': np.nan}
}
ex35A = pd.DataFrame(ex35)
ex35A.index.name = "Year"
ex35A.columns.name = "Revenues"

# %%
ex35A
# Out:
# Revenues  Company A  Company B  Company C
# Year
# 2018             90       33.0      273.0
# 2019             76        NaN       33.0
# 2020            109       13.0        NaN

# %% [markdown]
# ---
# ## Exercise 36:
# Based on the previous DataFrame use the pd.isna() function to map the missing data. Also show the amount of missing data in each column.

# %%
ex35A.isna()
# Out:
# Revenues  Company A  Company B  Company C
# Year
# 2018          False      False      False
# 2019          False       True      False
# 2020          False      False       True

# %%
ex35A.isna().sum()
# Out:
# Revenues
# Company A    0
# Company B    1
# Company C    1
# dtype: int64

# %% [markdown]
# ---
# ## Exercise 37:
# Based on DataFrame from exercise 35, do:
#
#
# a) replace the missing data with the average in the case Company B;
#
# b) replace the missing data with the median in the case of Company C;
#
# a) use idxmin() / idxmax() to filter the years i

# %%
ex35A["Company B"].fillna(ex35A["Company B"].mean(), inplace=True)
ex35A
# Out:
# Revenues  Company A  Company B  Company C
# Year
# 2018             90       33.0      273.0
# 2019             76       23.0       33.0
# 2020            109       13.0        NaN

# %%
ex35A["Company C"].fillna(ex35A["Company B"].median(), inplace=True)
ex35A
# Out:
# Revenues  Company A  Company B  Company C
# Year
# 2018             90       33.0      273.0
# 2019             76       23.0       33.0
# 2020            109       13.0       23.0

# %%
print('             Higher profits')
print(ex35A.idxmax())
# Out:
#              Higher profits
# Revenues
# Company A    2020
# Company B    2018
# Company C    2018
# dtype: object

# %%
print('             Lower profits')
print(ex35A.idxmin())
# Out:
#              Lower profits
# Revenues
# Company A    2019
# Company B    2020
# Company C    2020
# dtype: object

# %% [markdown]
# ---
# ## Exercise 38:
# The following Series represents a company's revenue over time. Obtain the line with the highest and lowest revenue, respectively.
#
#     2016-12-31    15
#     2017-12-31    31
#     2018-12-31    41
#     2019-12-31    47
#     2020-12-31    39
#     2021-12-31    10
#     2022-12-31    33
#     2023-12-31    13
#     2024-12-31    31
#     2025-12-31    33
#     Freq: A-DEC, dtype: int64

# %%
ex38 = pd.Series([15,31,41,17,39,10,33,13,31,33],
         index = pd.date_range(start= "2016", periods=10, freq = "Y"))

# %%
print('                        Year with highest revenue')
print(ex38.idxmax())
print('                        Year with lower revenue')
print(ex38.idxmin())
# Out:
#                         Year with highest revenue
# 2018-12-31 00:00:00
#                         Year with lower revenue
# 2021-12-31 00:00:00

# %% [markdown]
# ---
# ## Exercise 39:
# Remove the following lines from the Series object below:
# a) 'Year 1' line;
# b) then the lines 'Year 2' and 'Year 4'. Tip: df.drop().
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-12_23-55-15-1f2d5e6e878cd76e5961908a86d7f69a.png>

# %%
ex39 = pd.Series([143,134,147,129],
                index = ["Year " + str(i) for i in range(1,5)])
ex39
# Out:
# Year 1    143
# Year 2    134
# Year 3    147
# Year 4    129
# dtype: int64

# %%
ex39.drop("Year 1")
# Out:
# Year 2    134
# Year 3    147
# Year 4    129
# dtype: int64

# %%
ex39.drop(["Year 2", "Year 4"])
# Out:
# Year 1    143
# Year 3    147
# dtype: int64

# %% [markdown]
# ---
# ## Exercise 40:
# Based on the DataFrame below, do:
#
# a) delete the lines 'k' and 'j';
#
# b) delete columns 'A' and 'D'.
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-13_00-04-45-62d743a31ea534cd0f945b0a208c5e94.png>
#
# To build the data use:
#
#     import numpy as np
#     np.random.seed(77)
#
#     data = np.random.randint(1,50,16).reshape((4,4))

# %%
np.random.seed(77)
data = np.random.randint(1,50,16).reshape((4,4))
ex40 = pd.DataFrame(data, columns= list("ABCD"), index = list("ijkw"))
ex40
# Out:
#     A   B   C   D
# i  24  32  21  21
# j  44  38  25  32
# k  33  40  45  20
# w  33  37  37  48

# %%
ex40.drop(index = ["k","j"])
# Out:
#     A   B   C   D
# i  24  32  21  21
# w  33  37  37  48

# %%
ex40.drop(columns=["A","D"])
# Out:
#     B   C
# i  32  21
# j  38  25
# k  40  45
# w  37  37

# %% [markdown]
# ---
# ## Exercise 41:
# Use the pd.date_range() function to create the following DataFrame index (this function allows you to generate a date string - returning a DatetimeIndex object, with several applications in financial data analysis). As function arguments, specify:
#
#     start = '2020-12-01'
#
#     periods = 31
#
#     freq = 'D'
#
#
#     Then create the DataFrame below, knowing that the values follows a normal distribution with an average of 30, standard deviation 0.5, with 31 elements (Use the NumPy library). Generate a visualization for the data ( Use the function df.plot() ).
#
#
#     Use np.random.seed(21) to generate random numbers just like this exercise.
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-05-18_23-06-09-54e34521c9ac1c23a8bef21176cafbc2.png>

# %%
np.random.seed(21)
data41 = np.random.normal(30,0.5,31)
ex41 = pd.DataFrame(data41, index= pd.date_range("2020-12-01", periods=31, freq="D"), columns=["Values"])
ex41.head()
# Out:
#                Values
# 2020-12-01  29.974018
# 2020-12-02  29.944402
# 2020-12-03  30.520898
# 2020-12-04  29.371630
# 2020-12-05  30.372694

# %%
ex41.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---
# ## Exercise 42:
# Create a date_range () with the months of 2021 and store it in a variable. Change the freq argument to 'M'.

# %%
pd.date_range("2021-01-01", periods = 12, freq= "M")
# Out:
# DatetimeIndex(['2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31',
#                '2021-09-30', '2021-10-31', '2021-11-30', '2021-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %% [markdown]
# ---
# ## Exercise 43:
# Create a date_range () with the years 2010 to 2040 and store it in a variable. Change the freq argument to 'A'.

# %%
pd.date_range("2010-01-01", periods = 31, freq= "A")
# Out:
# DatetimeIndex(['2010-12-31', '2011-12-31', '2012-12-31', '2013-12-31',
#                '2014-12-31', '2015-12-31', '2016-12-31', '2017-12-31',
#                '2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31',
#                '2022-12-31', '2023-12-31', '2024-12-31', '2025-12-31',
#                '2026-12-31', '2027-12-31', '2028-12-31', '2029-12-31',
#                '2030-12-31', '2031-12-31', '2032-12-31', '2033-12-31',
#                '2034-12-31', '2035-12-31', '2036-12-31', '2037-12-31',
#                '2038-12-31', '2039-12-31', '2040-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %% [markdown]
# ---
# ## Exercise44:
# Build a DatetimeIndex for every day of September 2021 (year-month-day). Then build a Series with the date_range created.
#
#
# Expected result:
#
#     0    2021-09-01
#     1    2021-09-02
#     2    2021-09-03
#     3    2021-09-04
#     4    2021-09-05
#     5    2021-09-06
#     6    2021-09-07
#     7    2021-09-08
#     8    2021-09-09
#     9    2021-09-10
#     10   2021-09-11
#     11   2021-09-12
#     12   2021-09-13
#     13   2021-09-14
#     14   2021-09-15
#     15   2021-09-16
#     16   2021-09-17
#     17   2021-09-18
#     18   2021-09-19
#     19   2021-09-20
#     20   2021-09-21
#     21   2021-09-22
#     22   2021-09-23
#     23   2021-09-24
#     24   2021-09-25
#     25   2021-09-26
#     26   2021-09-27
#     27   2021-09-28
#     28   2021-09-29
#     dtype: datetime64[ns]

# %%
pd.Series(data = pd.date_range("2021-09-01", periods=30, freq="D"))
# Out:
# 0    2021-09-01
# 1    2021-09-02
# 2    2021-09-03
# 3    2021-09-04
# 4    2021-09-05
# 5    2021-09-06
# 6    2021-09-07
# 7    2021-09-08
# 8    2021-09-09
# 9    2021-09-10
# 10   2021-09-11
# 11   2021-09-12
# 12   2021-09-13
# 13   2021-09-14
# 14   2021-09-15
# 15   2021-09-16
# 16   2021-09-17
# 17   2021-09-18
# 18   2021-09-19
# 19   2021-09-20
# 20   2021-09-21
# 21   2021-09-22
# 22   2021-09-23
# 23   2021-09-24
# 24   2021-09-25
# 25   2021-09-26
# 26   2021-09-27
# 27   2021-09-28
# 28   2021-09-29
# 29   2021-09-30
# dtype: datetime64[ns]

# %% [markdown]
# ---
# ## Exercise 45:
# Build a DatetimeIndex for all 2021 quarters. Then build a Series with the created date_range.

# %%
pd.date_range("2021",periods= 4, freq="3M")
# Out:
# DatetimeIndex(['2021-01-31', '2021-04-30', '2021-07-31', '2021-10-31'], dtype='datetime64[ns]', freq='3M')

# %% [markdown]
# ---
# ## Exercise 46:
# Build a date_range() for December 31, 2030, with a range of 1 hour.

# %%
pd.date_range("2030-12-31",periods=24, freq="H")
# Out:
# DatetimeIndex(['2030-12-31 00:00:00', '2030-12-31 01:00:00',
#                '2030-12-31 02:00:00', '2030-12-31 03:00:00',
#                '2030-12-31 04:00:00', '2030-12-31 05:00:00',
#                '2030-12-31 06:00:00', '2030-12-31 07:00:00',
#                '2030-12-31 08:00:00', '2030-12-31 09:00:00',
#                '2030-12-31 10:00:00', '2030-12-31 11:00:00',
#                '2030-12-31 12:00:00', '2030-12-31 13:00:00',
#                '2030-12-31 14:00:00', '2030-12-31 15:00:00',
#                '2030-12-31 16:00:00', '2030-12-31 17:00:00',
#                '2030-12-31 18:00:00', '2030-12-31 19:00:00',
#                '2030-12-31 20:00:00', '2030-12-31 21:00:00',
#                '2030-12-31 22:00:00', '2030-12-31 23:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %% [markdown]
# ---
# ## Exercise 47:
# Build a date_range() from September to December 2020, following the business calendar, excluding Saturday and Sunday. Use the bdate_range() function.

# %%
pd.bdate_range("2020-09-01", end = "2020-12-31")
# Out:
# DatetimeIndex(['2020-09-01', '2020-09-02', '2020-09-03', '2020-09-04',
#                '2020-09-07', '2020-09-08', '2020-09-09', '2020-09-10',
#                '2020-09-11', '2020-09-14', '2020-09-15', '2020-09-16',
#                '2020-09-17', '2020-09-18', '2020-09-21', '2020-09-22',
#                '2020-09-23', '2020-09-24', '2020-09-25', '2020-09-28',
#                '2020-09-29', '2020-09-30', '2020-10-01', '2020-10-02',
#                '2020-10-05', '2020-10-06', '2020-10-07', '2020-10-08',
#                '2020-10-09', '2020-10-12', '2020-10-13', '2020-10-14',
#                '2020-10-15', '2020-10-16', '2020-10-19', '2020-10-20',
#                '2020-10-21', '2020-10-22', '2020-10-23', '2020-10-26',
#                '2020-10-27', '2020-10-28', '2020-10-29', '2020-10-30',
#                '2020-11-02', '2020-11-03', '2020-11-04', '2020-11-05',
#                '2020-11-06', '2020-11-09', '2020-11-10', '2020-11-11',
# ...

# %% [markdown]
# ---
# ## Exercise 48:
# Build a date_range() with the fortnights of the first half of 2021

# %%
pd.date_range("2021-01-01", periods= 12, freq="15D")
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-16', '2021-01-31', '2021-02-15',
#                '2021-03-02', '2021-03-17', '2021-04-01', '2021-04-16',
#                '2021-05-01', '2021-05-16', '2021-05-31', '2021-06-15'],
#               dtype='datetime64[ns]', freq='15D')

# %% [markdown]
# ---
# ## Exercise 49:
# Build the DataFrame below.
#
#
#             Date  Day of Year  Month of Year
#     0  2021-01-01           1           1
#     1  2021-01-16          16           1
#     2  2021-01-31          31           1
#     3  2021-02-15          46           2
#     4  2021-03-02          61           3
#     5  2021-03-17          76           3
#     6  2021-04-01          91           4
#     7  2021-04-16         106           4
#     8  2021-05-01         121           5
#     9  2021-05-16         136           5
#     10 2021-05-31         151           5
#     11 2021-06-15         166           6
#     12 2021-06-30         181           6
#     13 2021-07-15         196           7
#     14 2021-07-30         211           7
#     15 2021-08-14         226           8
#     16 2021-08-29         241           8
#     17 2021-09-13         256           9
#     18 2021-09-28         271           9
#     19 2021-10-13         286          10
#     20 2021-10-28         301          10
#     21 2021-11-12         316          11
#     22 2021-11-27         331          11
#     23 2021-12-12         346          12
#     24 2021-12-27         361          12

# %%
date = pd.date_range("2021-01-01", periods= 25, freq="15D")
day = date.day
month = date.month

# %%
dic = {
    "Date" : date,
    "Day of Year" : day,
    "Month of Year": month
}

# %%
pd.DataFrame(dic)
# Out:
#          Date  Day of Year  Month of Year
# 0  2021-01-01            1              1
# 1  2021-01-16           16              1
# 2  2021-01-31           31              1
# 3  2021-02-15           15              2
# 4  2021-03-02            2              3
# 5  2021-03-17           17              3
# 6  2021-04-01            1              4
# 7  2021-04-16           16              4
# 8  2021-05-01            1              5
# 9  2021-05-16           16              5
# 10 2021-05-31           31              5
# 11 2021-06-15           15              6
# 12 2021-06-30           30              6
# 13 2021-07-15           15              7
# 14 2021-07-30           30              7
# 15 2021-08-14           14              8
# 16 2021-08-29           29              8
# 17 2021-09-13           13              9
# 18 2021-09-28           28              9
# 19 2021-10-13           13             10
# 20 2021-10-28           28             10
# ...

# %% [markdown]
# ---
# ## Exercise 50:
# Build the DataFrame below, use the 'data' dictionary, and the date_range() function to build the index.
#
#     import numpy as np
#     n = 1096  #total observations
#     data = {
#         'A': np.random.randint(low = 1, high = 1500, size = n),
#         'B': np.random.normal(loc = 10, scale = 2, size = n),
#         'C': np.random.uniform(low = 0, high = 1, size = n),
#         'D': np.random.lognormal(mean = 4, sigma = 5, size = n),
#         'E': np.random.standard_normal(size = n)}
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-22_02-45-05-a71506c63dcb52c3cc567da8586496fb.png>

# %%
n = 1096  #total observations
data = {
    'A': np.random.randint(low = 1, high = 1500, size = n),
    'B': np.random.normal(loc = 10, scale = 2, size = n),
    'C': np.random.uniform(low = 0, high = 1, size = n),
    'D': np.random.lognormal(mean = 4, sigma = 5, size = n),
    'E': np.random.standard_normal(size = n)}
ex50 = pd.DataFrame(data, index = pd.date_range("2018-01-01", end = "2020-12-31", freq= "D"))
ex50
# Out:
#                A          B         C            D         E
# 2018-01-01   123  12.357112  0.712175  9673.667983  0.440042
# 2018-01-02   161   6.609441  0.974666     0.591805 -0.028939
# 2018-01-03  1137  10.861252  0.323200  1157.195001  0.131008
# 2018-01-04  1088   9.950727  0.397890  9448.886844  1.119929
# 2018-01-05   410  10.986563  0.418927     5.157740 -0.188766
# ...          ...        ...       ...          ...       ...
# 2020-12-27   928  13.777771  0.806810   635.594322  1.563861
# 2020-12-28   968  12.154227  0.107991  4329.602036  1.644871
# 2020-12-29   954   6.128865  0.958451     0.051761  1.501947
# 2020-12-30  1151   9.463430  0.701194     0.094440  0.078290
# 2020-12-31   235   5.314169  0.807629     0.220222 -0.814598
#
# [1096 rows x 5 columns]

# %% [markdown]
# ---
# ## Exercise 51:
# Based on the previous dataset, obtain:
#
#
#     descriptive statistics for each column;
#
#     dataset information;
#
#     correlation matrix(use df.corr);
#
#     covariance matrix(use df.cov).

# %%
ex50.describe()
# Out:
#                  A            B            C             D            E
# count  1096.000000  1096.000000  1096.000000  1.096000e+03  1096.000000
# mean    746.405109     9.958311     0.506764  6.357309e+05     0.028566
# std     436.806435     2.003111     0.284650  7.815501e+06     1.014025
# min       1.000000     3.616310     0.000386  5.758517e-06    -3.961118
# 25%     357.500000     8.675519     0.253374  1.789717e+00    -0.653433
# 50%     742.500000     9.947722     0.516888  5.166675e+01     0.011474
# 75%    1129.250000    11.390528     0.748416  1.428248e+03     0.748966
# max    1498.000000    17.025190     0.997096  2.246342e+08     3.759119

# %%
ex50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1096 entries, 2018-01-01 to 2020-12-31
# Freq: D
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1096 non-null   int32
#  1   B       1096 non-null   float64
#  2   C       1096 non-null   float64
#  3   D       1096 non-null   float64
#  4   E       1096 non-null   float64
# dtypes: float64(4), int32(1)
# memory usage: 47.1 KB

# %%
ex50.corr()
# Out:
#           A         B         C         D         E
# A  1.000000  0.036251 -0.035963 -0.054028  0.010424
# B  0.036251  1.000000 -0.034338  0.065457  0.019917
# C -0.035963 -0.034338  1.000000  0.039573  0.008902
# D -0.054028  0.065457  0.039573  1.000000 -0.038448
# E  0.010424  0.019917  0.008902 -0.038448  1.000000

# %%
ex50.cov()
# Out:
#               A             B             C             D              E
# A  1.907999e+05  3.171846e+01     -4.471588 -1.844439e+08       4.617293
# B  3.171846e+01  4.012454e+00     -0.019579  1.024751e+06       0.040456
# C -4.471588e+00 -1.957890e-02      0.081026  8.803771e+04       0.002570
# D -1.844439e+08  1.024751e+06  88037.713798  6.108205e+13 -304702.432012
# E  4.617293e+00  4.045619e-02      0.002570 -3.047024e+05       1.028247

# %% [markdown]
# ---
# ## Exercise 52:
# Use a loop to acquaints and print the Series values below. Their values follow a normal distribution with a mean of 10 and standard deviation of 0.5. Use np.random.seed (99) to reproduce the values for this exercise.
#
#
#     A     9.928821
#     B    11.028611
#     C    10.141631
#     D    10.664906
#     E     9.922689
#     F     9.965485
#     G    10.377590
#     H    10.412823
#     I     9.943465
#     J     8.816081
#     Name: Data, dtype: float64

# %%
np.random.seed(99)
ex52 = pd.Series(data = np.random.normal(10,0.5,10),index = list("ABCDEFGHIJ"))
ex52
# Out:
# A     9.928821
# B    11.028611
# C    10.141631
# D    10.664906
# E     9.922689
# F     9.965485
# G    10.377590
# H    10.412823
# I     9.943465
# J     8.816081
# dtype: float64

# %%
for number in ex52:
    print(round(number,2))
# Out:
# 9.93
# 11.03
# 10.14
# 10.66
# 9.92
# 9.97
# 10.38
# 10.41
# 9.94
# 8.82

# %% [markdown]
# ---
# ## Exercise 53:
# When Iterate on objects of type DataFrame we obtain the respective names of each column. Display the name of the DataFrame columns on the screen below. Use:
#
#
#     data = {
#         'W': np.random.randint(1,10,10),
#         'Z': np.random.uniform(0,10,10),
#         'K': np.linspace(1,50,10),
#         'J': np.arange(10),
#         'L': np.random.beta(1,10,10),
#         'M': np.random.exponential(1,10),
#         'Y': np.random.randint(-50,-1,10)
#     }
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-22_02-59-54-a95174bb9621f85275469eaf04466306.png>

# %%
data = {
    'W': np.random.randint(1,10,10),
    'Z': np.random.uniform(0,10,10),
    'K': np.linspace(1,50,10),
    'J': np.arange(10),
    'L': np.random.beta(1,10,10),
    'M': np.random.exponential(1,10),
    'Y': np.random.randint(-50,-1,10)
}
ex53 = pd.DataFrame(data, index = pd.date_range("2020-12-01", end = "2020-12-10"))
ex53
# Out:
#             W         Z          K  J         L         M   Y
# 2020-12-01  9  6.448347   1.000000  0  0.266708  0.346817 -10
# 2020-12-02  5  0.951816   6.444444  1  0.070572  0.174365 -23
# 2020-12-03  8  4.116632  11.888889  2  0.051361  0.362310 -50
# 2020-12-04  6  0.968653  17.333333  3  0.024803  1.267645 -36
# 2020-12-05  5  1.440110  22.777778  4  0.054955  3.169610  -9
# 2020-12-06  2  2.121962  28.222222  5  0.040888  0.015908 -18
# 2020-12-07  1  4.766562  33.666667  6  0.238423  0.374831 -14
# 2020-12-08  6  0.776138  39.111111  7  0.120640  0.050149 -23
# 2020-12-09  4  2.350438  44.555556  8  0.049486  2.077610 -33
# 2020-12-10  4  0.065530  50.000000  9  0.093592  1.183379 -37

# %%
for cols in ex53:
    print(cols)
# Out:
# W
# Z
# K
# J
# L
# M
# Y

# %% [markdown]
# ---
# ## Exercise 54:
# To Iterate over the rows of a DataFrame we can use the following functions:
#
#     iteritems(): Iterates over the DataFrame columns, returning a tuple with the column name and the content as a Series;
#
#     iterrows(): Iterate over DataFrame rows as (index, Series) pairs;
#
#     itertuples(): Iterate over DataFrame rows as namedtuples.
#
#
# Build the DataFrame below.
#
#       A  B  C
#     2020-12-31  0  1  2
#     2021-01-31  1  4  4
#     2021-02-28  2  9  6
#
#
# Build a script to Iterate over this, using iteritems() function.
#
# Expected result:
#
#
#     A
#     	Sum of values: 3
#     	Minimum value: 0
#     	Maximum value: 2
#     	Arithmetic mean of values: 1.0
#     	Standard deviation: 1.0
#
#     B
#     	Sum of values: 14
#     	Minimum value: 1
#     	Maximum value: 9
#     	Arithmetic mean of values: 4.67
#     	Standard deviation: 4.04
#
#     C
#     	Sum of values: 12
#     	Minimum value: 2
#     	Maximum value: 6
#     	Arithmetic mean of values: 4.0
#     	Standard deviation: 2.0

# %%
data = {
    "A" : [0,1,2],
    "B" : [1,4,9],
    "C" : [2,4,6]
}
ex54 = pd.DataFrame(data, index = pd.date_range("2020-12-31", end = "2021-02-28",freq = "M"))
ex54
# Out:
#             A  B  C
# 2020-12-31  0  1  2
# 2021-01-31  1  4  4
# 2021-02-28  2  9  6

# %%
for cols, values in ex54.iteritems():
    print(f"                      {cols}")
    print(f"Sum of values: {values.sum()}")
    print(f"Minimum Value: {values.min()}")
    print(f"maximum Value: {values.max()}")
    print(f"Arithmetic mean of values: {round(values.mean(),2)}")
    print(f"Standard deviation: {round(values.std(),2)}")
# Out:
#                       A
# Sum of values: 3
# Minimum Value: 0
# maximum Value: 2
# Arithmetic mean of values: 1.0
# Standard deviation: 1.0
#                       B
# Sum of values: 14
# Minimum Value: 1
# maximum Value: 9
# Arithmetic mean of values: 4.67
# Standard deviation: 4.04
#                       C
# Sum of values: 12
# Minimum Value: 2
# maximum Value: 6
# Arithmetic mean of values: 4.0
# Standard deviation: 2.0

# %% [markdown]
# ---
# ## Exercise 55:
# Build the DataFrame below.
#
#
#       A   B   C
#     2021-01-01   1   2   3
#     2021-01-02   4   5   6
#     2021-01-03   7   8   9
#     2021-01-04  10  11  12
#     2021-01-05  13  14  15
#     2021-01-06  16  17  18
#     2021-01-07  19  20  21
#     2021-01-08  22  23  24
#     2021-01-09  25  26  27
#     2021-01-10  28  29  30
#
# Then use iterrows() to get the sum of the values for each row:
#
# Expected output:
#
#     01/01/2021
#     Sum: 6
#
#     02/01/2021
#     Sum: 15
#
#     03/01/2021
#     Sum: 24
#
#     04/01/2021
#     Sum: 33
#
#     05/01/2021
#     Sum: 42
#
#     06/01/2021
#     Sum: 51
#
#     07/01/2021
#     Sum: 60
#
#     08/01/2021
#     Sum: 69
#
#     09/01/2021
#     Sum: 78
#
#     10/01/2021
#     Sum: 87

# %%
data = np.arange(1,31).reshape(10,3)
ex55 = pd.DataFrame(data, index = pd.date_range("2021-01-01", end = "2021-01-10"), columns = list("ABC"))
ex55
# Out:
#              A   B   C
# 2021-01-01   1   2   3
# 2021-01-02   4   5   6
# 2021-01-03   7   8   9
# 2021-01-04  10  11  12
# 2021-01-05  13  14  15
# 2021-01-06  16  17  18
# 2021-01-07  19  20  21
# 2021-01-08  22  23  24
# 2021-01-09  25  26  27
# 2021-01-10  28  29  30

# %%
for indx, values in ex55.iterrows():
    print(f"{indx.strftime('%Y/%m/%d')}")
    print(f"Sum: {values.sum()}")
    print()
# Out:
# 2021/01/01
# Sum: 6
#
# 2021/01/02
# Sum: 15
#
# 2021/01/03
# Sum: 24
#
# 2021/01/04
# Sum: 33
#
# 2021/01/05
# Sum: 42
#
# 2021/01/06
# Sum: 51
#
# 2021/01/07
# Sum: 60
#
# 2021/01/08
# Sum: 69
#
# 2021/01/09
# Sum: 78
#
# 2021/01/10
# Sum: 87

# %% [markdown]
# ---
# ## Exercise 56:
# Based on the previous DataFrame use itertuples() to obtain:
#
#
#     Pandas(Index=Timestamp('2021-01-01 00:00:00', freq='D'), A=1, B=2, C=3)
#     Pandas(Index=Timestamp('2021-01-02 00:00:00', freq='D'), A=4, B=5, C=6)
#     Pandas(Index=Timestamp('2021-01-03 00:00:00', freq='D'), A=7, B=8, C=9)
#     Pandas(Index=Timestamp('2021-01-04 00:00:00', freq='D'), A=10, B=11, C=12)
#     Pandas(Index=Timestamp('2021-01-05 00:00:00', freq='D'), A=13, B=14, C=15)
#     Pandas(Index=Timestamp('2021-01-06 00:00:00', freq='D'), A=16, B=17, C=18)
#     Pandas(Index=Timestamp('2021-01-07 00:00:00', freq='D'), A=19, B=20, C=21)
#     Pandas(Index=Timestamp('2021-01-08 00:00:00', freq='D'), A=22, B=23, C=24)
#     Pandas(Index=Timestamp('2021-01-09 00:00:00', freq='D'), A=25, B=26, C=27)
#     Pandas(Index=Timestamp('2021-01-10 00:00:00', freq='D'), A=28, B=29,

# %%
for tupl in ex55.itertuples():
    print(tupl)
# Out:
# Pandas(Index=Timestamp('2021-01-01 00:00:00', freq='D'), A=1, B=2, C=3)
# Pandas(Index=Timestamp('2021-01-02 00:00:00', freq='D'), A=4, B=5, C=6)
# Pandas(Index=Timestamp('2021-01-03 00:00:00', freq='D'), A=7, B=8, C=9)
# Pandas(Index=Timestamp('2021-01-04 00:00:00', freq='D'), A=10, B=11, C=12)
# Pandas(Index=Timestamp('2021-01-05 00:00:00', freq='D'), A=13, B=14, C=15)
# Pandas(Index=Timestamp('2021-01-06 00:00:00', freq='D'), A=16, B=17, C=18)
# Pandas(Index=Timestamp('2021-01-07 00:00:00', freq='D'), A=19, B=20, C=21)
# Pandas(Index=Timestamp('2021-01-08 00:00:00', freq='D'), A=22, B=23, C=24)
# Pandas(Index=Timestamp('2021-01-09 00:00:00', freq='D'), A=25, B=26, C=27)
# Pandas(Index=Timestamp('2021-01-10 00:00:00', freq='D'), A=28, B=29, C=30)

# %% [markdown]
# ---
# ## Exercise 57:
# Order the DataFrame below by index.
#
#
#     import pandas as pd
#     import numpy as np
#     days = pd.date_range(start = '2020-1-1', periods = 10).to_numpy()
#     np.random.shuffle(days)
#     df = pd.DataFrame(
#         data = np.random.normal(10,3.5,(10,3)),
#         columns = list('ABC'),
#         index = days)

# %%
days = pd.date_range(start = '2020-1-1', periods = 10).to_numpy()
np.random.shuffle(days)
ex57 = pd.DataFrame(
    data = np.random.normal(10,3.5,(10,3)),
    columns = list('ABC'),
    index = days)
ex57
# Out:
#                     A          B          C
# 2020-01-09  12.370805   8.141161  16.700725
# 2020-01-10   8.790874   7.298284   9.010724
# 2020-01-05   7.039521   8.232099  10.898853
# 2020-01-04   4.593295  14.522055   7.318182
# 2020-01-06  14.271575  12.343642  10.468822
# 2020-01-07  15.119690   9.310857   6.812875
# 2020-01-03  10.087231   5.744381   9.600521
# 2020-01-02  14.857492   3.424100   7.426703
# 2020-01-08  10.679169   8.717990  12.242658
# 2020-01-01  14.900063  11.548614   8.668812

# %%
ex57.sort_index()
# Out:
#                     A          B          C
# 2020-01-01  14.900063  11.548614   8.668812
# 2020-01-02  14.857492   3.424100   7.426703
# 2020-01-03  10.087231   5.744381   9.600521
# 2020-01-04   4.593295  14.522055   7.318182
# 2020-01-05   7.039521   8.232099  10.898853
# 2020-01-06  14.271575  12.343642  10.468822
# 2020-01-07  15.119690   9.310857   6.812875
# 2020-01-08  10.679169   8.717990  12.242658
# 2020-01-09  12.370805   8.141161  16.700725
# 2020-01-10   8.790874   7.298284   9.010724

# %% [markdown]
# ---
# ## Exercise 58:
# The dataset below stores information about the Brazilian football championship, series A, between 2017 and 2019. Based on these data, answer:
#
#
#     what is the average score of each team between 2017-2019?
#
#     what is the maximum and minimum score per year?
#
#     what is the average of points per year, among all the selected teams?
#
#     how many teams have been in the Top 5 each year?
#
#     obtain descriptive statistics of the score for each team (average, maximum, minimum, standard deviation, median), for the established time frame.
#
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-05-23_19-25-13-45ef878502c8d8ad3bfe1f79dff2503a.png>

# %%
data = {
    'Score':[56, 74, 63, 63, 72, 50, 63, 44, 80 ],
    'Rank':[8, 3, 6, 2, 1, 13, 5, 13, 1],
    'Year':[2019, 2019, 2019, 2017, 2017, 2017, 2018, 2018, 2018],
    'Team':['Corinthians', 'Palmeiras', 'São Paulo', 
            'Palmeiras', 'Corinthians', 'São Paulo',
            'São Paulo', 'Corinthians', 'Palmeiras']}
ex58 = pd.DataFrame(data)
ex58
# Out:
#    Score  Rank  Year         Team
# 0     56     8  2019  Corinthians
# 1     74     3  2019    Palmeiras
# 2     63     6  2019    São Paulo
# 3     63     2  2017    Palmeiras
# 4     72     1  2017  Corinthians
# 5     50    13  2017    São Paulo
# 6     63     5  2018    São Paulo
# 7     44    13  2018  Corinthians
# 8     80     1  2018    Palmeiras

# %%
ex58.groupby("Team")["Score"].mean().round(2)
# Out:
# Team
# Corinthians    57.33
# Palmeiras      72.33
# São Paulo      58.67
# Name: Score, dtype: float64

# %%
ex58.groupby("Year")["Score"].max()
# Out:
# Year
# 2017    72
# 2018    80
# 2019    74
# Name: Score, dtype: int64

# %%
ex58.groupby("Year")["Score"].min()
# Out:
# Year
# 2017    50
# 2018    44
# 2019    56
# Name: Score, dtype: int64

# %%
ex58.groupby("Year")["Score"].mean().round(2)
# Out:
# Year
# 2017    61.67
# 2018    62.33
# 2019    64.33
# Name: Score, dtype: float64

# %%
ex58[ex58["Rank"] >= 5].groupby("Team")["Team"].count()
# Out:
# Team
# Corinthians    2
# São Paulo      3
# Name: Team, dtype: int64

# %% [markdown]
# ---
# ## Exercise59:
# Build the following DataFrame objects.
#
# df1:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-22_12-18-07-16745e3b2db5099225c348400331a9c8.png>
#
# df2:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-22_12-21-17-eaab523b85fa16a51d807d8a8d44e231.png>
#
#     data1 = {
#         'A': ['A0','A1','A2','A3'],
#         'B': ['B0', 'B1', 'B2', 'B3'],
#         'C': ['C0', 'C1', 'C2', 'C3'],
#         }
#
#     data2 = {
#         'A':['A4', 'A5', 'A6', 'A7'],
#         'B':['B4', 'B5', 'B6', 'B7'],
#         'C':['C4', 'C5', 'C6', 'C7'],
#         }
#
#     index = [1, 2, 3, 4]
#
#
# Use the pd.concat() function to concatenate the data and obtain:
#
# a)
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-22_12-26-31-6020718ec129760c49066ec4a61ca66b.png>
# b)
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-22_12-27-18-27275c671a614f25e3488acc52def892.png>
#
# c)
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-22_12-28-54-03ea8dba024799348a101e8e36a0d1e2.png>
# d)
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-22_12-31-14-2dcc5427e0a67f4c92cc5a75f8a5ce4c.png>

# %%
data1 = {
    'A': ['A0','A1','A2','A3'],
    'B': ['B0', 'B1', 'B2', 'B3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    }

data2 = {
    'A':['A4', 'A5', 'A6', 'A7'],
    'B':['B4', 'B5', 'B6', 'B7'],
    'C':['C4', 'C5', 'C6', 'C7'],
    }

index = [1, 2, 3, 4]

ex59A = pd.DataFrame(data1, index)
ex59B = pd.DataFrame(data2, index)

# %%
print("                       A")
pd.concat([ex59A,ex59B], keys=["Group A","Group B"])
# Out:
#                        A
#             A   B   C
# Group A 1  A0  B0  C0
#         2  A1  B1  C1
#         3  A2  B2  C2
#         4  A3  B3  C3
# Group B 1  A4  B4  C4
#         2  A5  B5  C5
#         3  A6  B6  C6
#         4  A7  B7  C7

# %%
print("                       B")
pd.concat([ex59A,ex59B],ignore_index=True)
# Out:
#                        B
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 3  A3  B3  C3
# 4  A4  B4  C4
# 5  A5  B5  C5
# 6  A6  B6  C6
# 7  A7  B7  C7

# %%
print("                       C")
pd.concat([ex59A,ex59B],axis = 1)
# Out:
#                        C
#     A   B   C   A   B   C
# 1  A0  B0  C0  A4  B4  C4
# 2  A1  B1  C1  A5  B5  C5
# 3  A2  B2  C2  A6  B6  C6
# 4  A3  B3  C3  A7  B7  C7

# %%
print("                       D")
pd.concat([ex59A,ex59B],axis = 1, keys=["Group A","Group B"])
# Out:
#                        D
#   Group A         Group B
#         A   B   C       A   B   C
# 1      A0  B0  C0      A4  B4  C4
# 2      A1  B1  C1      A5  B5  C5
# 3      A2  B2  C2      A6  B6  C6
# 4      A3  B3  C3      A7  B7  C7

# %% [markdown]
# ---
# ## Exercise 60:
# Use the following DataFrame objects and use the pandas' append() function to concatenate the data and obtain:
#
#
#     import pandas as pd
#     index = [1, 2, 3]
#     df1 = pd.DataFrame({
#         'A': ['A0','A1','A2',],
#         'B': ['B0', 'B1', 'B2'],
#         'C': ['C0', 'C1', 'C2'],
#         }, index = index)
#
#     df2 = pd.DataFrame({
#         'A':['A3', 'A4', 'A5'],
#         'B':['B3', 'B4', 'B5'],
#         'C':['C3', 'C4', 'C5'],
#         }, index = index)
#
#     df3 = pd.DataFrame({
#         'A': ['A6', 'A7', 'A8'],
#         'B': ['B6', 'B7', 'B8'],
#         'C': ['C6', 'C7', 'C8']
#         }, index = index)
#
# a)
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-22_12-43-31-bf51dd85b10a9d3bb0ab778e72fecf34.png>
# b)
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-22_12-44-20-0170292a373f9d0557c45af055a96b9f.png>

# %%
index = [1, 2, 3]
ex60A = pd.DataFrame({
    'A': ['A0','A1','A2',],
    'B': ['B0', 'B1', 'B2'],
    'C': ['C0', 'C1', 'C2'],
    }, index = index)

ex60B = pd.DataFrame({
    'A':['A3', 'A4', 'A5'],
    'B':['B3', 'B4', 'B5'],
    'C':['C3', 'C4', 'C5'],
    }, index = index)

ex60C = pd.DataFrame({
    'A': ['A6', 'A7', 'A8'],
    'B': ['B6', 'B7', 'B8'],
    'C': ['C6', 'C7', 'C8']
    }, index = index)

# %%
ex60A.append(ex60B,ignore_index=True)
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 3  A3  B3  C3
# 4  A4  B4  C4
# 5  A5  B5  C5

# %%
ex60A.append([ex60B,ex60C])
# Out:
#     A   B   C
# 1  A0  B0  C0
# 2  A1  B1  C1
# 3  A2  B2  C2
# 1  A3  B3  C3
# 2  A4  B4  C4
# 3  A5  B5  C5
# 1  A6  B6  C6
# 2  A7  B7  C7
# 3  A8  B8  C8

# %% [markdown]
# ---
# ## Exercise 61:
# Show that the dataset below has missing data. Follow these steps:
#
#
#     Build the DataFrame;
#
#     Use the function isna(), isnull(), notna() or notnull() to check NaN in each column of the dataset;
#
#     Use the dropna() function to remove rows with missing data from the dataset.
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-05-23_20-36-48-84ae130742872a078e4466cc2857720e.png>
#     data = {
#         'A': [10, np.nan, 35, 47, 17, 13],
#         'B': ['A', np.nan, 'B', 'A', 'A', np.nan],
#         'C': [139, np.nan, np.nan, 199, 111, 140]}

# %%
data = {
        'A': [10, np.nan, 35, 47, 17, 13],
        'B': ['A', np.nan, 'B', 'A', 'A', np.nan],
        'C': [139, np.nan, np.nan, 199, 111, 140]
}
ex61 = pd.DataFrame(data, index = pd.date_range("2020-01-01", end = "2020-01-06"))
ex61
# Out:
#                A    B      C
# 2020-01-01  10.0    A  139.0
# 2020-01-02   NaN  NaN    NaN
# 2020-01-03  35.0    B    NaN
# 2020-01-04  47.0    A  199.0
# 2020-01-05  17.0    A  111.0
# 2020-01-06  13.0  NaN  140.0

# %%
ex61.isnull()
# Out:
#                 A      B      C
# 2020-01-01  False  False  False
# 2020-01-02   True   True   True
# 2020-01-03  False  False   True
# 2020-01-04  False  False  False
# 2020-01-05  False  False  False
# 2020-01-06  False   True  False

# %%
ex61.dropna()
# Out:
#                A  B      C
# 2020-01-01  10.0  A  139.0
# 2020-01-04  47.0  A  199.0
# 2020-01-05  17.0  A  111.0

# %% [markdown]
# ---
# ## Exercise 62:
# Create a function that receives a DataFrame object and return the percentage of missings in each column of the dataset. If the object is from the class of pandas.core.frame.DataFrame show the missing data calculation, otherwise return None. Test the function with the previous dataset.

# %%
def check_miss(data):
    if type(data) == type(pd.DataFrame()):
        return data.isna().sum()/ data.shape[0]*100
    else:
        return None

# %%
check_miss(ex61)
# Out:
# A    16.666667
# B    33.333333
# C    33.333333
# dtype: float64

# %% [markdown]
# ---
# ## Exercise 63:
# With the dataset for exercise 61, replace all NaN with the value 0.

# %%
ex61.fillna(0)
# Out:
#                A  B      C
# 2020-01-01  10.0  A  139.0
# 2020-01-02   0.0  0    0.0
# 2020-01-03  35.0  B    0.0
# 2020-01-04  47.0  A  199.0
# 2020-01-05  17.0  A  111.0
# 2020-01-06  13.0  0  140.0

# %% [markdown]
# ---
# ## Exercise 64:
# Based on the DataFrame below, use the fillna () function to fill in the missing data in each column, according to the following rules:
#
#
#     column A: replace NaN with the average of the values;
#
#     column B: replace NaN with the mode of values;
#
#     column C: replace NaN with category 'A';
#
#     column D: replace NaN with the median of the values.
#
#     import numpy as np
#     data = {
#         'A':[np.nan, 10, 11, 9, 17, 21, np.nan, np.nan],
#         'B':[np.nan, np.nan, 1, 1, 1, 0, np.nan, 1],
#         'C':['A', 'B', 'B','A',np.nan, np.nan,np.nan,'A'],
#         'D':[169, 133, np.nan, 172, np.nan, 133, 174, 170]}
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2020-12-22_13-07-25-adab26b3596c2fe679a7692159a7571c.png>

# %%
data = {
    'A':[np.nan, 10, 11, 9, 17, 21, np.nan, np.nan],
    'B':[np.nan, np.nan, 1, 1, 1, 0, np.nan, 1],
    'C':['A', 'B', 'B','A',np.nan, np.nan,np.nan,'A'],
    'D':[169, 133, np.nan, 172, np.nan, 133, 174, 170]}
ex64 = pd.DataFrame(data)
ex64
# Out:
#       A    B    C      D
# 0   NaN  NaN    A  169.0
# 1  10.0  NaN    B  133.0
# 2  11.0  1.0    B    NaN
# 3   9.0  1.0    A  172.0
# 4  17.0  1.0  NaN    NaN
# 5  21.0  0.0  NaN  133.0
# 6   NaN  NaN  NaN  174.0
# 7   NaN  1.0    A  170.0

# %%
ex64["A"].fillna(ex64["A"].mean(),inplace = True)
ex64
# Out:
#       A    B    C      D
# 0  13.6  NaN    A  169.0
# 1  10.0  NaN    B  133.0
# 2  11.0  1.0    B    NaN
# 3   9.0  1.0    A  172.0
# 4  17.0  1.0  NaN    NaN
# 5  21.0  0.0  NaN  133.0
# 6  13.6  NaN  NaN  174.0
# 7  13.6  1.0    A  170.0

# %%
ex64["B"].fillna(ex64["B"].mode()[0],inplace= True)
ex64
# Out:
#       A    B    C      D
# 0  13.6  1.0    A  169.0
# 1  10.0  1.0    B  133.0
# 2  11.0  1.0    B    NaN
# 3   9.0  1.0    A  172.0
# 4  17.0  1.0  NaN    NaN
# 5  21.0  0.0  NaN  133.0
# 6  13.6  1.0  NaN  174.0
# 7  13.6  1.0    A  170.0

# %%
ex64["C"].fillna("A",inplace= True)
ex64
# Out:
#       A    B  C      D
# 0  13.6  1.0  A  169.0
# 1  10.0  1.0  B  133.0
# 2  11.0  1.0  B    NaN
# 3   9.0  1.0  A  172.0
# 4  17.0  1.0  A    NaN
# 5  21.0  0.0  A  133.0
# 6  13.6  1.0  A  174.0
# 7  13.6  1.0  A  170.0

# %%
ex64["D"].fillna(ex64["D"].median(),inplace= True)
ex64
# Out:
#       A    B  C      D
# 0  13.6  1.0  A  169.0
# 1  10.0  1.0  B  133.0
# 2  11.0  1.0  B  169.5
# 3   9.0  1.0  A  172.0
# 4  17.0  1.0  A  169.5
# 5  21.0  0.0  A  133.0
# 6  13.6  1.0  A  174.0
# 7  13.6  1.0  A  170.0

# %% [markdown]
# ---
# ## Exercise 65:
# Based on DataFrame below:
#
#     remove duplicate lines;
#
#     change the "W brand" ID to 11;
#
#     sort the DataFrame by the Rating column;
#
#     change the DataFrame index to the 'ID' column;
#
#     convert the DataFrame to a dictionary and store it in a variable.
#
#
#     import pandas as pd
#
#     data = {
#         'Brand': ['A', 'A', 'D', 'W', 'K'],
#         'ID': [1, 1, 3, 5, 7],
#         'Rating':[3.5, 3.5, 4, 8.2, 1]}
#
#     df = pd.DataFrame(data)

# %%
data = {
    'Brand': ['A', 'A', 'D', 'W', 'K'],
    'ID': [1, 1, 3, 5, 7],
    'Rating':[3.5, 3.5, 4, 8.2, 1]}
ex65 = pd.DataFrame(data)
ex65
# Out:
#   Brand  ID  Rating
# 0     A   1     3.5
# 1     A   1     3.5
# 2     D   3     4.0
# 3     W   5     8.2
# 4     K   7     1.0

# %%
ex65.drop_duplicates(inplace= True)
ex65
# Out:
#   Brand  ID  Rating
# 0     A   1     3.5
# 2     D   3     4.0
# 3     W   5     8.2
# 4     K   7     1.0

# %%
ex65.at[3, "ID"] = 11
ex65
# Out:
#   Brand  ID  Rating
# 0     A   1     3.5
# 2     D   3     4.0
# 3     W  11     8.2
# 4     K   7     1.0

# %%
ex65
# Out:
#   Brand  ID  Rating
# 0     A   1     3.5
# 2     D   3     4.0
# 3     W  11     8.2
# 4     K   7     1.0

# %%
ex65.sort_values("Rating", inplace= True)
ex65
# Out:
#   Brand  ID  Rating
# 4     K   7     1.0
# 0     A   1     3.5
# 2     D   3     4.0
# 3     W  11     8.2

# %%
ex65.set_index("ID", inplace= True)
ex65
# Out:
#    Brand  Rating
# ID
# 7      K     1.0
# 1      A     3.5
# 3      D     4.0
# 11     W     8.2

# %%
dic_65 = ex65.to_dict()
dic_65
# Out:
# {'Brand': {7: 'K', 1: 'A', 3: 'D', 11: 'W'},
#  'Rating': {7: 1.0, 1: 3.5, 3: 4.0, 11: 8.2}}

# %% [markdown]
# ---
# ## Exercise 66-70:
# 1. Use the pd.read_csv () function to load the insurance.csv dataset, attached in this lesson; store in a variable;
#
# 2. Show the number of rows and columns (shape);
#
# 3. Show basic information of the dataset with the info () function;
#
# 4. Show the dtype of each column;
#
# 5. Show the columns of the dataset;
#
# 6. Show statistical information in the 'age' column;
#
# 7. Print the unique values ​​for each column, with the exception of the 'bmi' column;
#
# 8. Show the age distribution (use: value_counts());
#
# 9. Check for missing data in the dataset;
#
# 10. Check for duplicate rows in the DataFrame, if there are duplicate rows delete;
#
# 11. Show the variables with the data type object;
#
# 12. Show only the numeric columns of the dataset;
#
# 13. Convert the numeric columns to a list;
#
# 14. Convert non-numeric columns to a list;
#
# 15. Convert the dtype of the sex, smoker and region variables to category; double check the column dtype;
#
# 16. Show descriptive statistics for categorical columns;
#
# 17. Show descriptive statistics for numerical columns;
#
# 18. Show the proportion between men and women;
#
# 19. Return all persons aged 62 or over;
#
# 20. Return all persons aged 18 years old;
#
# 21. Count how many people reside in the 'southwest' region;
#
# 22. Order the DataFrame by the 'age' column in ascending order;
#
# 23. Visualize the age distribution using a plot boxplot;
#
# 24. Visualize the age distribution using histogram.

# %%
#1
insurance = pd.read_csv("Datasets/insurance.csv")
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#2
insurance.shape
# Out:
# (1338, 7)

# %%
#3
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#4
insurance.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
#5 
insurance.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
#6
insurance["age"].describe()
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
#7
for col in ['age', 'sex', 'children', 'smoker', 'region', 'charges']:
    print(f"{col}: {insurance[col].unique()}")
# Out:
# age: [19 18 28 33 32 31 46 37 60 25 62 23 56 27 52 30 34 59 63 55 22 26 35 24
#  41 38 36 21 48 40 58 53 43 64 20 61 44 57 29 45 54 49 47 51 42 50 39]
# sex: ['female' 'male']
# children: [0 1 3 2 5 4]
# smoker: ['yes' 'no']
# region: ['southwest' 'southeast' 'northwest' 'northeast']
# charges: [16884.924   1725.5523  4449.462  ...  1629.8335  2007.945  29141.3603]

# %%
#8
insurance["age"].value_counts()
# Out:
# 18    69
# 19    68
# 20    29
# 51    29
# 45    29
# 46    29
# 47    29
# 48    29
# 50    29
# 52    29
# 28    28
# 54    28
# 21    28
# 27    28
# 26    28
# 49    28
# 25    28
# 24    28
# 23    28
# 22    28
# 53    28
# 42    27
# 44    27
# 43    27
# 41    27
# 40    27
# 31    27
# 30    27
# 29    27
# 56    26
# 34    26
# 33    26
# 32    26
# 57    26
# 55    26
# 35    25
# 59    25
# 58    25
# 36    25
# 39    25
# 38    25
# 37    25
# 60    23
# 61    23
# 62    23
# 63    23
# 64    22
# Name: age, dtype: int64

# %%
#9
insurance.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#10
print(insurance.duplicated().sum())
insurance.drop_duplicates(inplace=True)
# Out:
# 1

# %%
#11
insurance.select_dtypes("object")
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1337 rows x 3 columns]

# %%
#12
insurance.select_dtypes(["int64","float"])
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1337 rows x 4 columns]

# %%
#13
list_numeric = insurance.select_dtypes(["int64","float"]).columns.to_list()
list_numeric
# Out:
# ['age', 'bmi', 'children', 'charges']

# %%
#14
list_non_numeric = insurance.select_dtypes(exclude = ["int64","float"]).columns.to_list()
list_non_numeric
# Out:
# ['sex', 'smoker', 'region']

# %%
#15
for col in list_non_numeric:
    insurance[col] = insurance[col].astype("category")
insurance.dtypes
# Out:
# age            int64
# sex         category
# bmi          float64
# children       int64
# smoker      category
# region      category
# charges      float64
# dtype: object

# %%
#16
insurance[list_non_numeric].describe()
# Out:
#          sex smoker     region
# count   1337   1337       1337
# unique     2      2          4
# top     male     no  southeast
# freq     675   1063        364

# %%
#17
insurance[list_numeric].describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#18
insurance["sex"].value_counts()
# Out:
# male      675
# female    662
# Name: sex, dtype: int64

# %%
#19
insurance[insurance["age"] > 62]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 26     63  female  23.085         0     no  northeast  14451.83515
# 33     63    male  28.310         0     no  northwest  13770.09790
# 62     64    male  24.700         1     no  northwest  30166.61817
# 94     64  female  31.300         2    yes  southwest  47291.05500
# 109    63    male  35.090         0    yes  southeast  47055.53210
# 170    63    male  41.470         0     no  southeast  13405.39030
# 175    63  female  37.700         0    yes  southwest  48824.45000
# 199    64  female  39.330         0     no  northeast  14901.51670
# 208    63  female  31.800         0     no  southwest  13880.94900
# 244    63  female  27.740         0    yes  northeast  29523.16560
# 251    63  female  32.200         2    yes  southwest  47305.30500
# 287    63  female  26.220         0     no  northwest  14256.19280
# 328    64  female  33.800         1    yes  southwest  47928.03000
# ...

# %%
#20
insurance[insurance["age"] == 18]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 22     18    male  34.100         0     no  southeast   1137.01100
# 31     18  female  26.315         0     no  northeast   2198.18985
# 46     18  female  38.665         2     no  northeast   3393.35635
# 50     18  female  35.625         0     no  northeast   2211.13075
# ...   ...     ...     ...       ...    ...        ...          ...
# 1296   18    male  26.125         0     no  northeast   1708.92575
# 1315   18    male  28.310         1     no  northeast  11272.33139
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
#
# [69 rows x 7 columns]

# %%
#21
insurance[insurance["region"] == "southeast"].count()[0]
# Out:
# 364

# %%
#22
insurance.sort_values("age", inplace= True)
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 866    18    male  37.290         0     no  southeast   1141.44510
# 1023   18    male  23.320         1     no  southeast   1711.02680
# 1150   18  female  30.305         0     no  northeast   2203.73595
# 1080   18    male  21.780         2     no  southeast  11884.04858
# 710    18    male  35.200         1     no  southeast   1727.54000
# ...   ...     ...     ...       ...    ...        ...          ...
# 420    64    male  33.880         0    yes  southeast  46889.26120
# 62     64    male  24.700         1     no  northwest  30166.61817
# 199    64  female  39.330         0     no  northeast  14901.51670
# 94     64  female  31.300         2    yes  southwest  47291.05500
# 664    64  female  22.990         0    yes  southeast  27037.91410
#
# [1337 rows x 7 columns]

# %%
#23
insurance.boxplot("age")
# Out:
# <AxesSubplot:>

# %%
#24
insurance.hist("age", bins = 30,grid= False)
# Out:
# array([[<AxesSubplot:title={'center':'age'}>]], dtype=object)
