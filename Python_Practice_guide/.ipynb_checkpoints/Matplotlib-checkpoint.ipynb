# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## Exercise 1:
# Use the following arrays to build a line graph. Use the Matplotlib library and configure the title with plt.title(), and the description of the axes with plt.xlabel() and plt.ylabel().
#
#
#     import numpy as np
#     x = np.arange(-5.0, 5.0, 0.01)
#     y = np.sin(np.pi*x)

# %%
x = np.arange(-5.0, 5.0, 0.01)
y = np.sin(np.pi*x)
plt.plot(x,y)
plt.title("Plot1")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
# Out:
# Text(0, 0.5, 'Y Axis')

# %% [markdown]
# ---
# ## Exercise 2:
# Use the following arrays to build a line graph. Within the plt.plot() function change the marker to 'o', (marker = 'o') and the line color to 'black' (color = 'black').
#
#
#     import matplotlib.pyplot as plt
#     import numpy as np
#
#     x = np.arange(20)
#     y = np.random.randint(1,100, 20)
#
#
# Expected result:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-13_23-11-07-842ca505e46298459d6107a13f363e46.jpeg>

# %%
x = np.arange(20)
y = np.random.randint(1,100, 20)
plt.plot(x,y, marker = 'o', color = 'black')
plt.title("Plot1")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
# Out:
# Text(0, 0.5, 'Y Axis')

# %% [markdown]
# ---
# ## Exercise 3:
# Use the following arrays to build a line graph. Inside the plt.plot() function the line style for '--' (use linestyle = '--' or ls = '--').
#
#
#     import numpy as np
#     y = np.random.normal(100, 5, 30)
#
#
# Expected result:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-13_23-30-24-df533e7f81c70dea2c1e467b16d3ca53.jpeg>

# %%
x = np.arange(30)
y = np.random.normal(100, 5, 30)
plt.plot(x,y, marker = 'o', color = 'red', linestyle = "--")
plt.title("Plot1")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
# Out:
# Text(0, 0.5, 'Y Axis')

# %% [markdown]
# ---
# ## Exercise 4:
# Use the DataFrame below to build a line graph, for the values in the 'Brand 1' column as a function of time.
#
#
#     import matplotlib.pyplot as plt
#     import pandas as pd
#     import numpy as np
#     n = 100
#     columns = ['Brand '+str(number) for number in range(1,5)]
#     date = pd.date_range(start = '2021-1-1', periods = n)
#     data = np.random.randint(low = 1, high = [100, 330, 45, 77], size = (n, 4))
#     df = pd.DataFrame(data,columns = columns, index = date)
#
#
# Expected result:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-13_23-31-31-fe8ebbb6462502f272795fbb491ce8ef.jpeg>

# %%
n = 100
columns = ['Brand '+str(number) for number in range(1,5)]
date = pd.date_range(start = '2021-1-1', periods = n)
data = np.random.randint(low = 1, high = [100, 330, 45, 77], size = (n, 4))
df = pd.DataFrame(data,columns = columns, index = date)
df
# Out:
#             Brand 1  Brand 2  Brand 3  Brand 4
# 2021-01-01        6      118       16       43
# 2021-01-02       92      154       37       36
# 2021-01-03       25      154       15       14
# 2021-01-04       21      320       42       70
# 2021-01-05       89        3       16       51
# ...             ...      ...      ...      ...
# 2021-04-06       59      211        8       15
# 2021-04-07       61      199       15       41
# 2021-04-08       31      144       12       50
# 2021-04-09        7      185       35       16
# 2021-04-10       96        7       16        7
#
# [100 rows x 4 columns]

# %%
plt.figure(figsize=(12,5))
plt.plot(df["Brand 1"])
plt.title("Brand A")
plt.xlabel("Time")
plt.ylabel("Values")
# Out:
# Text(0, 0.5, 'Values')

# %% [markdown]
# ---
# ## Exercise 5:
# Build a bar chart with the DataFrame from the previous exercise. Use the plt.bar() function
#
#
# Expected Result:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-13_23-32-08-71b0482aa10f76ef76e2322bf6c7fd83.jpeg>

# %%
data = df.sum().sort_values(ascending = False)
data
# Out:
# Brand 2    14196
# Brand 1     4959
# Brand 4     4010
# Brand 3     2155
# dtype: int64

# %%
plt.bar(x = data.index, height = data)
plt.xlabel("Brands")
plt.ylabel("Values")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# ---
# ## Exercise 6:
# Build a horizontal bar graph with the DataFrame from the previous exercise. Use the plt.barh() function.
#
#
# Expected result:
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-13_23-33-54-214552ad2647551990e19222077545f1.jpeg>

# %%
plt.barh(y = data.index, width = data)
plt.ylabel("Brands")
plt.xlabel("Values")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# ---
# ## Exercise 7:
# Use the code below to build a scatter plot. Use the plt.scatter() function and set the marker to '^' (marker = '^') and the opacity to 0.3 (alpha = 0.3). Use plt.grid() to configure the grid lines.
#
#
#     from sklearn.datasets import make_regression
#     X, y = make_regression(n_samples = 100, n_features = 1, noise = 20)
#
#
# Expected results:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-13_23-47-12-38d630eea0532706eb1430aa70092e96.jpeg>

# %%
from sklearn.datasets import make_regression
X, y = make_regression(n_samples = 100, n_features = 1, noise = 20)
plt.scatter(X,y,marker = "^", alpha = 0.3, color = "k")
plt.xlabel('Feature')
plt.ylabel('Target')
plt.grid(True, linestyle = "--")

# %% [markdown]
# ---
# ## Exercise 8:
# With the data below build a histogram. Use the plt.hist() function.
#
#
#     import numpy as np
#     data = np.random.normal(loc = 100, scale = 0.5, size = 100)
#
#
# Expected result::
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-13_23-56-26-b1b09124073abd227ca56abb21c12c85.jpeg>

# %%
data = np.random.normal(loc = 100, scale = 0.5, size = 100)
plt.hist(data)
plt.title("Histogram")
plt.xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# ---
# ## Exercise 9:
# Use the data below to build the chart below. Change the font size to 15 on the axes and 20 on the title. Use the plt.legend() function to insert a legend on the chart, use the loc argument to set the position. Possibilities for setting the loc argument: best, upper right, upper left, lower left, lower right, right, center left, center right, lower center, upper center, center.
#
#
#     import numpy as np
#     import matplotlib.pyplot as plt
#
#     x = np.arange(1,11)
#     y1 = x**2
#     y2 = x**3
#     y3 = x**4
#
#
# Expected result:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-14_17-15-15-6420b0f1a325646c27f9dc091b935269.jpeg>

# %%
x = np.arange(1,11)
y1 = x**2
y2 = x**3
y3 = x**4

# %%
plt.plot(y1,"o",y2,"^",y3,"bs")
plt.legend(["y1","y2","y3"])
plt.grid(True,color = "red", linestyle = "--", alpha = 0.8)
plt.xlabel("X", fontsize = 15)
plt.ylabel("Y", fontsize = 15)
plt.title("Values", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Values')

# %% [markdown]
# ---
# ## Exercise 10:
# Replicate the graph below and use the plt.savefig () function to save the result.
#
#
#     brand_A = [120, 130, 145, 177, 270, 211]
#     brand_B = [90, 41, 140, 150, 230, 193]
#     months = ['January','February','March','April','May','June']
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-14_19-35-56-f19c87a711107390a84274049fce53f6.jpeg >

# %%
brand_A = [120, 130, 145, 177, 270, 211]
brand_B = [90, 41, 140, 150, 230, 193]
months = ['January','February','March','April','May','June']

# %%
plt.bar(x = months, height= brand_A, color = "blue")
plt.bar(x = months, height= brand_B, color = "red")
plt.title("Revenue over Time")
plt.savefig("revenue.png")

# %% [markdown]
# ---
# ## Exercise 11:
# Use the data below to build a pie chart. Use the plt.pie() function and save the obtained figure.
#
#
#     sales = [1500.2, 1378, 671, 431, 700]
#     labels = ['Brand '+str(number) for number in range(1,len(sales)+1)]
#
#
# Expected result:
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-14_17-40-20-e971e813a41d506318d7ea84ca0b991b.jpeg>

# %%
sales = [1500.2, 1378, 671, 431, 700]
labels = ['Brand '+str(number) for number in range(1,len(sales)+1)]
plt.pie(x = sales, labels=labels)
plt.show()

# %% [markdown]
# ---
# ## Exercise 12:
# Go back to the previous graph and add captions with the function plt.legend() (loc = 'upper left'), change the shadow argument to True and show the percentage of sales for each brand.

# %%
sales = [1500.2, 1378, 671, 431, 700]
labels = ['Brand '+str(number) for number in range(1,len(sales)+1)]
plt.figure(figsize=(9,6))
plt.pie(x = sales, labels=labels, shadow= True, autopct='%1.0f%%')
plt.title("Pie Chart")
plt.legend(loc = "upper left",shadow =True)
plt.show()

# %% [markdown]
# ---
# ## Exercise 13:
# Build the DataFrame below. Subsequently draw up the graph below. Change the limit of the y axis to 80-100, with the function plt.ylim(), and the size of the figure to (15.5) (use plt.figure (figsize = (15.5)).
#
#
#     import numpy as np
#     np.random.seed(7)
#     data = np.random.randint(low = 100, high = [250, 300, 500, 1000], size = (12, 4))
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-14_19-55-20-c697fae4c532bd64956eaaa86a94baa1.png>
#
#
# Expected result:
#
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-14_19-56-54-3ae370e2bfb1b9b2f542da16eee128c3.jpeg>

# %%
np.random.seed(7)
data = np.random.randint(low = 100, high = [250, 300, 500, 1000], size = (12, 4))
index = pd.date_range(start = '2021-1-1', periods = 12, freq = 'M').month_name()
ex13 = pd.DataFrame(data,index, columns=list("ABCD"))
ex13
# Out:
#              A    B    C    D
# January    125  167  311  715
# February   192  285  498  635
# March      172  189  466  654
# April      236  267  168  532
# May        227  235  100  175
# June       155  106  375  544
# July       144  291  425  924
# August     212  289  390  412
# September  138  104  237  955
# October    172  183  357  804
# November   244  218  449  704
# December   171  123  110  845

# %%
plt.figure(figsize=(15,5))
plt.plot(ex13["A"])
plt.plot(ex13["B"])
plt.plot(ex13["C"])
plt.plot(ex13["D"])
plt.grid(alpha = 0.5, linestyle = "--")
plt.legend(list("ABCD"))
plt.ylim(80, 1000)
# Out:
# (80.0, 1000.0)

# %% [markdown]
# ---
# ## Exercise 14:
# With the previous DataFrame, build: a) bar graph; b) horizontal bar graph; c) pie chart.
#
# a)
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-14_20-09-17-be3db836eaa8224ff5a129dc3ab1dd08.jpeg>
# b)
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-14_20-09-29-b58b97ae077d4e2ede406d53261a7fb2.jpeg>
# c)
#
# <img src = https://img-c.udemycdn.com/redactor/raw/article_lecture/2021-01-14_20-09-59-d94e873751d5314a05122baf059aaf9d.jpeg>

# %%
data = ex13.sum()

# %%
plt.bar(data.index, data)
plt.title("Bar plot")
# Out:
# Text(0.5, 1.0, 'Bar plot')

# %%
plt.barh(data.index, data)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.pie(data,autopct='%1.2f%%', explode = (0, 0.1, 0.1, 0.1))
plt.legend(data.index, loc = "upper left")

# %% [markdown]
# ---
# ## Exercise 15:
#
#     Load the attached Iris dataset in this lesson.
#
#     Remove the Id column;
#
#     Make a bar graph to show the frequency of the three Iris species in the dataset;
#
#     Make a horizontal bar graph to obtain the previous result.

# %%
iris = pd.read_csv("Datasets/Iris_matplolib.csv")
iris.drop(columns = "Id",inplace = True)
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data_iris = iris.value_counts("Species")

# %%
plt.bar(data_iris.index, data_iris)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(data_iris.index, data_iris)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ---
# ## Exercise 16:
#
#     Make a pie chart to show the frequency of the three Iris species in the dataset;
# ---
# ## Exercise 17:
#
#     Make a scatter plot to show the relation between 'SepalLengthCm' and 'SepalWidthCm';
# ---
# ## Exercise 18
#
#     Make a scatter plot to show the relation between 'PetalLengthCm' and 'PetalWidthCm'.
# ---
# ## Exercise 19
#
#     Show the histogram of the dataset's features (exclusive Species column).
# ---
# ## Exercise 20
#
#     Show the boxplot of the dataset's features (exclusive Species column).

# %%
# 16
plt.pie(data_iris,
       labels = data_iris.index,
       autopct= "%.2f%%")
plt.legend(loc = "upper left")
plt.show()

# %%
# 17
plt.scatter(x = "SepalLengthCm", y= "SepalWidthCm", data = iris)

# %%
# 18
plt.scatter(x = "PetalLengthCm", y= "PetalWidthCm", data = iris)

# %%
numerical_data = iris.select_dtypes("float64")

# %%
# 19
for cols in numerical_data.columns:
    plt.hist(iris[cols], bins=15)
    plt.title(cols)
    plt.show()

# %%
# 20
for cols in numerical_data.columns:
    plt.boxplot(iris[cols])
    plt.title(cols)
    plt.show()

# %% [markdown]
# ---
# Load the attached dataset in this class and then do:
#
#     import pandas as pd
#     series = pd.read_csv( 'Airline_passengers.csv' , header=0, index_col=0, parse_dates=True,
#     squeeze=True)
# ---
# ## Exercise 21:
#
#     Present the descriptive statistics of the time series with the describe () function;
#
#     Show the shape of the dataset.
# ---
# ## Exercise 22
#
#     Make a line graph to demonstrate the evolution of the variable 'Airline-passengers' over time.
# ----
# ## Exercise 23
#
#     Make a boxplot characterize the variable 'Airline-passengers'.
# ----
# ## Exercise 24
#
#     Make a histogram and a kde plot.
# ---
# ## Exercise 25
#
#     Import the lag_plot function and apply the time series (this function generates a lag plot for time series.)
#
#     from pandas.plotting import lag_plot

# %%
series = pd.read_csv( 'Datasets/Airline_passengers.csv' , header=0, index_col=0, parse_dates=True,
squeeze=True)

# %%
series
# Out:
# Month
# 1949-01-01    112.0
# 1949-02-01    118.0
# 1949-03-01    132.0
# 1949-04-01    129.0
# 1949-05-01    121.0
#               ...
# 1960-08-01    606.0
# 1960-09-01    508.0
# 1960-10-01    461.0
# 1960-11-01    390.0
# 1960-12-01    432.0
# Name: Airline_passengers, Length: 144, dtype: float64

# %%
# 21
series.describe()
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: Airline_passengers, dtype: float64

# %%
series.shape
# Out:
# (144,)

# %%
# 22
plt.plot(series)
plt.title("Airline-passengers")
plt.grid(True, color = "grey", alpha = 0.5,linestyle = "--")

# %%
# 23
plt.boxplot(series)
plt.xlabel("Airline-passengers")
# Out:
# Text(0.5, 0, 'Airline-passengers')

# %%
# 24
plt.hist(series)
plt.xlabel("Airline-passengers")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import seaborn as sns

# %%
sns.kdeplot(series)
# Out:
# <AxesSubplot:xlabel='Airline_passengers', ylabel='Density'>

# %%
# 25
from pandas.plotting import lag_plot

# %%
lag_plot(series)
plt.grid(linestyle = "--")
