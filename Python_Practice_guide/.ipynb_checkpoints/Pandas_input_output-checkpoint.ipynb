# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## Exercise 1:
# The database has information about the distribution of respirators for the Covid-19 treatment  in Brazil. Based on this dataset, do:
#
#
# Read the dataset with the pd.read_csv () function and store it in a df variable;
#
#
#     Print the first 10 lines;
#
#     Print the last 3 lines;
#
#     Print the columns of the dataset;
#
#     Show information about the df object;
#
#     Show the data type of each column;
#
#     Show the number of lines of the df object;
#
#     Show the amount of missing in each column of the DataFrame.
#
# Download the dataset attached in this class to solve this exercise.

# %%
respirators = pd.read_csv("Datasets/respirators_distribution_Brazil.csv", delimiter=";")

# %%
#1
respirators.head(10)
# Out:
#          DATA FORNECEDOR         DESTINO ESTADO/MUNICIPIO        TIPO  \
# 0  19/04/2020     VYAIRE  RIO DE JANEIRO           ESTADO         UTI
# 1  22/04/2020     VYAIRE  RIO DE JANEIRO           ESTADO         UTI
# 2  08/05/2020   MAGNAMED  RIO DE JANEIRO           ESTADO         UTI
# 3  08/05/2020        KTK  RIO DE JANEIRO           ESTADO         UTI
# 4  09/05/2020   LEISTUNG  RIO DE JANEIRO           ESTADO         UTI
# 5  09/05/2020     VYAIRE  RIO DE JANEIRO           ESTADO         UTI
# 6  09/05/2020     VYAIRE  RIO DE JANEIRO           ESTADO         UTI
# 7  09/05/2020   MAGNAMED  RIO DE JANEIRO           ESTADO         UTI
# 8  09/05/2020   MAGNAMED  RIO DE JANEIRO           ESTADO  TRANSPORTE
# 9  09/05/2020   MAGNAMED  RIO DE JANEIRO           ESTADO         UTI
#
#    QUANTIDADE    VALOR                                       DESTINATARIO  UF
# 0          40  2400000  ALMOXARIFADO ESTADUAL DE MEDICAMENTOS - RIO DE...  RJ
# ...

# %%
#2
respirators.tail(3)
# Out:
#             DATA           FORNECEDOR DESTINO ESTADO/MUNICIPIO  \
# 1602  24/09/2020                  KTK  PARANA        MUNICIPIO
# 1603  24/09/2020  VYAIRE LTV 2200 USA  PARANA        MUNICIPIO
# 1604  07/08/2020             MAGNAMED  LIBANO                -
#
#                 TIPO  QUANTIDADE     VALOR  \
# 1602             UTI           2    120000
# 1603  TRANSPORTE USA           1     63125
# 1604      TRANSPORTE         300  14487000
#
#                                 DESTINATARIO  UF
# 1602                           SMS de GUAIRA  PR
# 1603                           SMS de GUAIRA  PR
# 1604  MISSÃO FAB (Doação Destino ao Libano).   -

# %%
#1
respirators.columns
# Out:
# Index(['DATA', 'FORNECEDOR', 'DESTINO', 'ESTADO/MUNICIPIO', 'TIPO',
#        'QUANTIDADE', 'VALOR', 'DESTINATARIO', 'UF'],
#       dtype='object')

# %%
respirators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1605 entries, 0 to 1604
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DATA              1605 non-null   object
#  1   FORNECEDOR        1605 non-null   object
#  2   DESTINO           1605 non-null   object
#  3   ESTADO/MUNICIPIO  1605 non-null   object
#  4   TIPO              1605 non-null   object
#  5   QUANTIDADE        1605 non-null   int64
#  6   VALOR             1605 non-null   int64
#  7   DESTINATARIO      1605 non-null   object
#  8   UF                1605 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 113.0+ KB

# %%
respirators.dtypes
# Out:
# DATA                object
# FORNECEDOR          object
# DESTINO             object
# ESTADO/MUNICIPIO    object
# TIPO                object
# QUANTIDADE           int64
# VALOR                int64
# DESTINATARIO        object
# UF                  object
# dtype: object

# %%
respirators.shape[0]
# Out:
# 1605

# %%
respirators.isna().sum()
# Out:
# DATA                0
# FORNECEDOR          0
# DESTINO             0
# ESTADO/MUNICIPIO    0
# TIPO                0
# QUANTIDADE          0
# VALOR               0
# DESTINATARIO        0
# UF                  0
# dtype: int64

# %% [markdown]
# ---
# ## Exercise 2:
# Still with the previous dataset follow the steps below:
#
#
#     Convert the 'DATA' (date) column to datetime;
#
#     Convert the 'VALOR' (value) column to float;
#
#     Show the unique values in the 'FORNECEDOR' (supplier) column;
#
#     Show the unique values of the 'TIPO' (type) column;
#
#     Show the number of unique recipients (column 'DESTINATÁRIOS').

# %%
#1
respirators["DATA"] = pd.to_datetime(respirators["DATA"])

# %%
#2
respirators["VALOR"] = respirators["VALOR"].astype("float64")

# %%
respirators.dtypes
# Out:
# DATA                datetime64[ns]
# FORNECEDOR                  object
# DESTINO                     object
# ESTADO/MUNICIPIO            object
# TIPO                        object
# QUANTIDADE                   int64
# VALOR                      float64
# DESTINATARIO                object
# UF                          object
# dtype: object

# %%
#3
respirators["FORNECEDOR"].unique()
# Out:
# array(['VYAIRE', 'MAGNAMED', 'KTK', 'LEISTUNG', 'LEISTUNG/VYAIRE',
#        'KTK/VAYIRE', 'WEG', 'VYAIRE LTV 2200 USA', 'UTI',
#        'VYAIRE LTV 1200 USA', 'MAGNAMED-REQUISIÇÃO',
#        'SUZANO/Zhongxun Medical', 'SUZANO/Resmed',
#        'L C DADDE COM AT INST MAT MEDICO EPP', 'MAGNAMED/REQUISIÇÃO',
#        'Leistung'], dtype=object)

# %%
#4
respirators["TIPO"].unique()
# Out:
# array(['UTI', 'TRANSPORTE', 'TRANSPORTE USA', 'Transporte'], dtype=object)

# %%
#5
respirators["DESTINATARIO"].nunique()
# Out:
# 944

# %% [markdown]
# ---
# ## Exercise 3:
# After the operations performed in exercises 1 and 2, save the database in CSV format with the name 'respirators_distribution_Brazil-modified.csv'. Use ';' as a separator.

# %%
respirators.to_csv("Respirators_Brazil", sep=";")

# %% [markdown]
# ---
# ## Exercise 4:
# After the operations performed in exercises 1 and 2, convert the database to Excel format.

# %%
respirators.to_excel("Respirators_Brazil.xlsx")

# %% [markdown]
# ---
# ## Exercise 5:
#     Load the CardioGoodFitness database attached in this class;
#
#     Print the number of rows and columns of the dataset;
#
#     Print the first 3 lines of the DataFrame;
#
#     Print the last 2 lines of the DataFrame;
#
#     Print the data type for each column;
#
#     Convert the Income column to float;
#
#     Print the unique values of the Product column;
#
#     Print the unique values of the MaritalStatus column;
#
#     Print the proportion of men and women.

# %%
cardio = pd.read_csv("Datasets/CardioGoodFitness.csv")

# %%
#1
cardio.shape
# Out:
# (180, 9)

# %%
#2
cardio.head(3)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66

# %%
#3
cardio.tail(2)
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 178    120
# 179    180

# %%
#4
cardio.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
#5 
cardio["Income"] = cardio["Income"].astype("float64")

# %%
cardio.dtypes
# Out:
# Product           object
# Age                int64
# Gender            object
# Education          int64
# MaritalStatus     object
# Usage              int64
# Fitness            int64
# Income           float64
# Miles              int64
# dtype: object

# %%
#6
cardio["Product"].unique()
# Out:
# array(['TM195', 'TM498', 'TM798'], dtype=object)

# %%
#7
cardio["MaritalStatus"].unique()
# Out:
# array(['Single', 'Partnered'], dtype=object)

# %%
cardio["Gender"].value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %% [markdown]
# ---
# ## Exercise 6:
# After the operations performed in exercise 5, convert the database to the Json format.

# %%
cardio.to_json("CardioGood.json")

# %% [markdown]
# ---
# ## Exercise 7:
# Use the pd.read_html() function to obtain the main US economic indicators between 1980-2020 (estimate). Use the link as a reference:
#
# https://en.wikipedia.org/wiki/Economy_of_the_United_States.

# %%
economy_us = pd.read_html("https://en.wikipedia.org/wiki/Economy_of_the_United_States")[1]
economy_us
# Out:
#           Year  Nominal GDP(billions USD)  GDP per capita(USD)  \
# 0   2020 (est)                    20934.0                57589
# 1         2019                    21439.0                64674
# 2         2018                    20611.2                62869
# 3         2017                    19519.4                60000
# 4         2016                    18715.0                57878
# 5         2015                    18224.8                56770
# 6         2014                    17521.3                54993
# 7         2013                    16784.9                52737
# 8         2012                    16155.3                51404
# 9         2011                    15517.9                49736
# 10        2010                    14964.4                48311
# 11        2009                    14418.7                46909
# 12        2008                    14718.6                48302
# 13        2007                    14477.6                47955
# ...

# %% [markdown]
# ---
# ## Exercise 8:
# Save the previous spread sheet in CSV format.

# %%
economy_us.to_csv("Economy_US.csv", sep=";")

# %% [markdown]
# ---
# ## Exercise 9:
# Download the dataset attached in this lesson, which was generated from the FAOSTAT that refers to database production and selected commodities productivity for some countries, between 2016-2018.
#
# Follow the steps below:
#
#
#     Read the dataset and store it in a variable;
#
#     Print the shape of the dataset;
#
#     Print dataset information;
#
#     Print the data type for each column;
#
#     Remove the columns: 'Domain Code', 'Domain', 'Area Code', 'Element Code', 'Item Code', 'Year Code', 'Flag', 'Flag Description';
#
#     Convert the dtype from the Value column to float.

# %%
faostat = pd.read_csv("Datasets/FAOSTAT_data_12-5-2020.csv")
faostat.head()
# Out:
#   Domain Code Domain  Area Code       Area  Element Code     Element  \
# 0          QC  Crops          9  Argentina          5419       Yield
# 1          QC  Crops          9  Argentina          5419       Yield
# 2          QC  Crops          9  Argentina          5419       Yield
# 3          QC  Crops          9  Argentina          5510  Production
# 4          QC  Crops          9  Argentina          5510  Production
#
#    Item Code    Item  Year Code  Year    Unit   Value Flag Flag Description
# 0        515  Apples       2016  2016   hg/ha  223912   Fc  Calculated data
# 1        515  Apples       2017  2017   hg/ha  235386   Fc  Calculated data
# 2        515  Apples       2018  2018   hg/ha  213072   Fc  Calculated data
# 3        515  Apples       2016  2016  tonnes  458908  NaN    Official data
# 4        515  Apples       2017  2017  tonnes  458908  NaN    Official data

# %%
faostat.shape
# Out:
# (66, 14)

# %%
faostat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       66 non-null     object
#  1   Domain            66 non-null     object
#  2   Area Code         66 non-null     int64
#  3   Area              66 non-null     object
#  4   Element Code      66 non-null     int64
#  5   Element           66 non-null     object
#  6   Item Code         66 non-null     int64
#  7   Item              66 non-null     object
#  8   Year Code         66 non-null     int64
#  9   Year              66 non-null     int64
#  10  Unit              66 non-null     object
#  11  Value             66 non-null     int64
#  12  Flag              43 non-null     object
#  13  Flag Description  66 non-null     object
# dtypes: int64(6), object(8)
# memory usage: 7.3+ KB

# %%
faostat.dtypes
# Out:
# Domain Code         object
# Domain              object
# Area Code            int64
# Area                object
# Element Code         int64
# Element             object
# Item Code            int64
# Item                object
# Year Code            int64
# Year                 int64
# Unit                object
# Value                int64
# Flag                object
# Flag Description    object
# dtype: object

# %%
faostat.drop(columns=["Domain Code","Domain","Area Code","Element Code", "Item Code", "Year Code", "Flag", "Flag Description"],inplace= True)

# %%
faostat
# Out:
#                         Area     Element      Item  Year    Unit     Value
# 0                  Argentina       Yield    Apples  2016   hg/ha    223912
# 1                  Argentina       Yield    Apples  2017   hg/ha    235386
# 2                  Argentina       Yield    Apples  2018   hg/ha    213072
# 3                  Argentina  Production    Apples  2016  tonnes    458908
# 4                  Argentina  Production    Apples  2017  tonnes    458908
# ..                       ...         ...       ...   ...     ...       ...
# 61  United States of America       Yield  Tomatoes  2017   hg/ha    886625
# 62  United States of America       Yield  Tomatoes  2018   hg/ha    968079
# 63  United States of America  Production  Tomatoes  2016  tonnes  12877049
# 64  United States of America  Production  Tomatoes  2017  tonnes  11141862
# 65  United States of America  Production  Tomatoes  2018  tonnes  12612139
#
# [66 rows x 6 columns]

# %%
faostat["Value"] = faostat["Value"].astype("float64")

# %%
faostat
# Out:
#                         Area     Element      Item  Year    Unit       Value
# 0                  Argentina       Yield    Apples  2016   hg/ha    223912.0
# 1                  Argentina       Yield    Apples  2017   hg/ha    235386.0
# 2                  Argentina       Yield    Apples  2018   hg/ha    213072.0
# 3                  Argentina  Production    Apples  2016  tonnes    458908.0
# 4                  Argentina  Production    Apples  2017  tonnes    458908.0
# ..                       ...         ...       ...   ...     ...         ...
# 61  United States of America       Yield  Tomatoes  2017   hg/ha    886625.0
# 62  United States of America       Yield  Tomatoes  2018   hg/ha    968079.0
# 63  United States of America  Production  Tomatoes  2016  tonnes  12877049.0
# 64  United States of America  Production  Tomatoes  2017  tonnes  11141862.0
# 65  United States of America  Production  Tomatoes  2018  tonnes  12612139.0
#
# [66 rows x 6 columns]

# %% [markdown]
# ---
# ## Exercise 10:
# After the operations performed in exercise 9, save the dataset in CSV format.

# %%
faostat.to_csv("Faostat.csv", sep=";")
